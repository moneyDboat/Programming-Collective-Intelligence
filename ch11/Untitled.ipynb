# %%
import gp 
from imp import reload
reload(gp)

exampletree = gp.exampletree()
print(exampletree.evaluate([5,3]))
exampletree.display()
# Out:
# 8
# if
#  isgreater
#   p0
#   3
#  add
#   p1
#   5
#  subtract
#   p1
#   2

# %%
tree = gp.makerandomtree(2)
tree.display()
# Out:
# if
#  multiply
#   if
#    4
#    if
#     p0
#     p1
#     10
#    0
#   p0
#  add
#   multiply
#    isgreater
#     4
#     0
#    add
#     6
#     p0
#   multiply
#    4
#    multiply
#     p0
#     p0
#  p0

# %%
hiddenset = gp.buildhiddenset()
rf = gp.getrankfunction(hiddenset)
evolve_tree = gp.evolve(2, 500, rf, mutationrate=0.2, breedingrate=0.1, pexp=0.7, pnew=0.1)
gp.drawgptree(evolve_tree, jpeg='output/evtree')
# Out:
# iter 0 : 21162.000000
# iter 1 : 5620.000000
# iter 2 : 5226.000000
# iter 3 : 4826.000000
# iter 4 : 4802.000000
# iter 5 : 4802.000000
# iter 6 : 4790.000000
# iter 7 : 4790.000000
# iter 8 : 3768.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-47419d58e346> in <module>()
#       1 hiddenset = gp.buildhiddenset()
#       2 rf = gp.getrankfunction(hiddenset)
# ----> 3 evolve_tree = gp.evolve(2, 500, rf, mutationrate=0.2, breedingrate=0.1, pexp=0.7, pnew=0.1)
#       4 gp.drawgptree(evolve_tree, jpeg='output/evtree')
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in evolve(pc, popsize, rankfunction, maxgen, mutationrate, breedingrate, pexp, pnew)
#     217                               scores[selectindex()][1],
#     218                               probswap=breedingrate),
# --> 219                     pc, probchange=mutationrate))
#     220             else:
#     221                 # Add a random node to mix things up
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in mutate(t, pc, probchange)
#     169         result = deepcopy(t)
#     170         if hasattr(t, "children"):
# --> 171             result.children = [mutate(c, pc, probchange) for c in t.children]
#     172         return result
#     173
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in <listcomp>(.0)
#     169         result = deepcopy(t)
#     170         if hasattr(t, "children"):
# --> 171             result.children = [mutate(c, pc, probchange) for c in t.children]
#     172         return result
#     173
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in mutate(t, pc, probchange)
#     169         result = deepcopy(t)
#     170         if hasattr(t, "children"):
# --> 171             result.children = [mutate(c, pc, probchange) for c in t.children]
#     172         return result
#     173
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in <listcomp>(.0)
#     169         result = deepcopy(t)
#     170         if hasattr(t, "children"):
# --> 171             result.children = [mutate(c, pc, probchange) for c in t.children]
#     172         return result
#     173
#
# /Users/Captain/Desktop/Programming-Collective-Intelligence/ch11/gp.py in mutate(t, pc, probchange)
#     167         return makerandomtree(pc)
#     168     else:
# --> 169         result = deepcopy(t)
#     170         if hasattr(t, "children"):
#     171             result.children = [mutate(c, pc, probchange) for c in t.children]
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# //anaconda/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# //anaconda/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# //anaconda/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# //anaconda/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# //anaconda/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# //anaconda/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# //anaconda/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     172                     reductor = getattr(x, "__reduce_ex__", None)
#     173                     if reductor:
# --> 174                         rv = reductor(4)
#     175                     else:
#     176                         reductor = getattr(x, "__reduce__", None)
#
# KeyboardInterrupt:

# %%
test = [(14,exampletree),(13, gp.constnode(4))]
test.sort()

# %%
test[0][0]
# Out:
# 13
