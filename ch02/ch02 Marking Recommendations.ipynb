# %% [markdown]
# # 提供推荐

# %% [markdown]
# ## 基于用户的协作型过滤
# 核心思想：找出和自己品味相近的一群人

# %%
from pprint import pprint
# A dictionary of movie critics and their ratings of a small
# set of movies
critics={'Lisa Rose': {'Lady in the Water': 2.5, 'Snakes on a Plane': 3.5,
 'Just My Luck': 3.0, 'Superman Returns': 3.5, 'You, Me and Dupree': 2.5, 
 'The Night Listener': 3.0},
'Gene Seymour': {'Lady in the Water': 3.0, 'Snakes on a Plane': 3.5, 
 'Just My Luck': 1.5, 'Superman Returns': 5.0, 'The Night Listener': 3.0, 
 'You, Me and Dupree': 3.5}, 
'Michael Phillips': {'Lady in the Water': 2.5, 'Snakes on a Plane': 3.0,
 'Superman Returns': 3.5, 'The Night Listener': 4.0},
'Claudia Puig': {'Snakes on a Plane': 3.5, 'Just My Luck': 3.0,
 'The Night Listener': 4.5, 'Superman Returns': 4.0, 
 'You, Me and Dupree': 2.5},
'Mick LaSalle': {'Lady in the Water': 3.0, 'Snakes on a Plane': 4.0, 
 'Just My Luck': 2.0, 'Superman Returns': 3.0, 'The Night Listener': 3.0,
 'You, Me and Dupree': 2.0}, 
'Jack Matthews': {'Lady in the Water': 3.0, 'Snakes on a Plane': 4.0,
 'The Night Listener': 3.0, 'Superman Returns': 5.0, 'You, Me and Dupree': 3.5},
'Toby': {'Snakes on a Plane':4.5,'You, Me and Dupree':1.0,'Superman Returns':4.0}}
pprint(critics)
# Out:
# {'Claudia Puig': {'Just My Luck': 3.0,
#                   'Snakes on a Plane': 3.5,
#                   'Superman Returns': 4.0,
#                   'The Night Listener': 4.5,
#                   'You, Me and Dupree': 2.5},
#  'Gene Seymour': {'Just My Luck': 1.5,
#                   'Lady in the Water': 3.0,
#                   'Snakes on a Plane': 3.5,
#                   'Superman Returns': 5.0,
#                   'The Night Listener': 3.0,
#                   'You, Me and Dupree': 3.5},
#  'Jack Matthews': {'Lady in the Water': 3.0,
#                    'Snakes on a Plane': 4.0,
#                    'Superman Returns': 5.0,
#                    'The Night Listener': 3.0,
#                    'You, Me and Dupree': 3.5},
#  'Lisa Rose': {'Just My Luck': 3.0,
#                'Lady in the Water': 2.5,
#                'Snakes on a Plane': 3.5,
#                'Superman Returns': 3.5,
#                'The Night Listener': 3.0,
#                'You, Me and Dupree': 2.5},
#  'Michael Phillips': {'Lady in the Water': 2.5,
#                       'Snakes on a Plane': 3.0,
#                       'Superman Returns': 3.5,
#                       'The Night Listener': 4.0},
#  'Mick LaSalle': {'Just My Luck': 2.0,
#                   'Lady in the Water': 3.0,
#                   'Snakes on a Plane': 4.0,
#                   'Superman Returns': 3.0,
#                   'The Night Listener': 3.0,
#                   'You, Me and Dupree': 2.0},
#  'Toby': {'Snakes on a Plane': 4.5,
#           'Superman Returns': 4.0,
#           'You, Me and Dupree': 1.0}}

# %%
from math import sqrt

# Returns a distance-based similarity score for person1 and person2
def sim_distance(prefs,person1,person2):
  # Get the list of shared_items
  si={}
  for item in prefs[person1]: 
    if item in prefs[person2]: si[item]=1

  # if they have no ratings in common, return 0
  if len(si)==0: return 0

  # Add up the squares of all the differences
  sum_of_squares=sum([pow(prefs[person1][item]-prefs[person2][item],2) 
                      for item in prefs[person1] if item in prefs[person2]])

  return 1/(1+sum_of_squares)

# %%
sim_distance(critics,'Lisa Rose','Gene Seymour')
names = list(critics.keys())
for person1 in names:
    for person2 in names:
        if person1 == person2:
            break
        distance = sim_distance(critics,person1,person2)
        print('%f : %s and %s.' %(distance,person1,person2))
# Out:
# 0.210526 : Gene Seymour and Michael Phillips.
# 0.444444 : Lisa Rose and Michael Phillips.
# 0.148148 : Lisa Rose and Gene Seymour.
# 0.181818 : Jack Matthews and Michael Phillips.
# 0.800000 : Jack Matthews and Gene Seymour.
# 0.210526 : Jack Matthews and Lisa Rose.
# 0.285714 : Mick LaSalle and Michael Phillips.
# 0.129032 : Mick LaSalle and Gene Seymour.
# 0.333333 : Mick LaSalle and Lisa Rose.
# 0.137931 : Mick LaSalle and Jack Matthews.
# 0.571429 : Claudia Puig and Michael Phillips.
# 0.133333 : Claudia Puig and Gene Seymour.
# 0.285714 : Claudia Puig and Lisa Rose.
# 0.181818 : Claudia Puig and Jack Matthews.
# 0.173913 : Claudia Puig and Mick LaSalle.
# 0.285714 : Toby and Michael Phillips.
# 0.108108 : Toby and Gene Seymour.
# 0.222222 : Toby and Lisa Rose.
# 0.117647 : Toby and Jack Matthews.
# 0.307692 : Toby and Mick LaSalle.
# 0.235294 : Toby and Claudia Puig.

# %%
# Returns the Pearson correlation coefficient for p1 and p2
def sim_pearson(prefs,p1,p2):
  # Get the list of mutually rated items
  si={}
  for item in prefs[p1]: 
    if item in prefs[p2]: si[item]=1

  # if they are no ratings in common, return 0
  if len(si)==0: return 0

  # Sum calculations
  n=len(si)
  
  # Sums of all the preferences
  sum1=sum([prefs[p1][it] for it in si])
  sum2=sum([prefs[p2][it] for it in si])
  
  # Sums of the squares
  sum1Sq=sum([pow(prefs[p1][it],2) for it in si])
  sum2Sq=sum([pow(prefs[p2][it],2) for it in si])	
  
  # Sum of the products
  pSum=sum([prefs[p1][it]*prefs[p2][it] for it in si])
  
  # Calculate r (Pearson score)
  num=pSum-(sum1*sum2/n)
  den=sqrt((sum1Sq-pow(sum1,2)/n)*(sum2Sq-pow(sum2,2)/n))
  if den==0: return 0

  r=num/den

  return r

# %%
for person1 in names:
    for person2 in names:
        if person1 == person2:
            break
        distance = sim_pearson(critics,person1,person2)
        print('%f : %s and %s.' %(distance,person1,person2))
# Out:
# 0.204598 : Gene Seymour and Michael Phillips.
# 0.404520 : Lisa Rose and Michael Phillips.
# 0.396059 : Lisa Rose and Gene Seymour.
# 0.134840 : Jack Matthews and Michael Phillips.
# 0.963796 : Jack Matthews and Gene Seymour.
# 0.747018 : Jack Matthews and Lisa Rose.
# -0.258199 : Mick LaSalle and Michael Phillips.
# 0.411765 : Mick LaSalle and Gene Seymour.
# 0.594089 : Mick LaSalle and Lisa Rose.
# 0.211289 : Mick LaSalle and Jack Matthews.
# 1.000000 : Claudia Puig and Michael Phillips.
# 0.314970 : Claudia Puig and Gene Seymour.
# 0.566947 : Claudia Puig and Lisa Rose.
# 0.028571 : Claudia Puig and Jack Matthews.
# 0.566947 : Claudia Puig and Mick LaSalle.
# -1.000000 : Toby and Michael Phillips.
# 0.381246 : Toby and Gene Seymour.
# 0.991241 : Toby and Lisa Rose.
# 0.662849 : Toby and Jack Matthews.
# 0.924473 : Toby and Mick LaSalle.
# 0.893405 : Toby and Claudia Puig.

# %%
# Returns the best matches for person from the prefs dictionary. 
# Number of results and similarity function are optional params.
def topMatches(prefs,person,n=5,similarity=sim_pearson):
  scores=[(similarity(prefs,person,other),other) 
                  for other in prefs if other!=person]
  scores.sort()
  scores.reverse()
  return scores[0:n]

# My own funtion
def myTopMatches(data,similarity=sim_pearson):
    names = list(data.keys())
    results = {}
    
    for person1 in names:
        for person2 in names:
            if person1 == person2:
                break
            results[person1+' and '+person2]=similarity(data,person1,person2)

    #dict sorted by value of key
    return sorted(results.items(),key=lambda d:d[1],reverse=True)

# %%
results = myTopMatches(critics,sim_pearson)
pprint(results)
# Out:
# [('Claudia Puig and Michael Phillips', 1.0),
#  ('Toby and Lisa Rose', 0.9912407071619299),
#  ('Jack Matthews and Gene Seymour', 0.963795681875635),
#  ('Toby and Mick LaSalle', 0.9244734516419049),
#  ('Toby and Claudia Puig', 0.8934051474415647),
#  ('Jack Matthews and Lisa Rose', 0.7470178808339965),
#  ('Toby and Jack Matthews', 0.66284898035987),
#  ('Mick LaSalle and Lisa Rose', 0.5940885257860044),
#  ('Claudia Puig and Mick LaSalle', 0.5669467095138411),
#  ('Claudia Puig and Lisa Rose', 0.5669467095138396),
#  ('Mick LaSalle and Gene Seymour', 0.41176470588235276),
#  ('Lisa Rose and Michael Phillips', 0.40451991747794525),
#  ('Lisa Rose and Gene Seymour', 0.39605901719066977),
#  ('Toby and Gene Seymour', 0.38124642583151164),
#  ('Claudia Puig and Gene Seymour', 0.31497039417435607),
#  ('Mick LaSalle and Jack Matthews', 0.21128856368212925),
#  ('Gene Seymour and Michael Phillips', 0.20459830184114206),
#  ('Jack Matthews and Michael Phillips', 0.13483997249264842),
#  ('Claudia Puig and Jack Matthews', 0.02857142857142857),
#  ('Mick LaSalle and Michael Phillips', -0.2581988897471611),
#  ('Toby and Michael Phillips', -1.0)]

# %%
# Gets recommendations for a person by using a weighted average
# of every other user's rankings
def getRecommendations(prefs,person,similarity=sim_pearson):
  totals={}
  simSums={}
  for other in prefs:
    # don't compare me to myself
    if other==person: continue
    sim=similarity(prefs,person,other)

    # ignore scores of zero or lower
    if sim<=0: continue
    for item in prefs[other]:
  
      # only score movies I haven't seen yet
      if item not in prefs[person] or prefs[person][item]==0:
        # Similarity * Score
        totals.setdefault(item,0)
        totals[item]+=prefs[other][item]*sim
        # Sum of similarities
        simSums.setdefault(item,0)
        simSums[item]+=sim

  # Create the normalized list
  rankings=[(item,total/simSums[item]) for item,total in totals.items()]

  # Return the sorted list
  rankings.sort()
  rankings.reverse()
  return rankings

# %%
getRecommendations(critics,'Toby')
# Out:
# [('The Night Listener', 3.3477895267131013),
#  ('Lady in the Water', 2.8325499182641614),
#  ('Just My Luck', 2.5309807037655645)]

# %%
def transformPrefs(prefs):
  result={}
  for person in prefs:
    for item in prefs[person]:
      result.setdefault(item,{})
      
      # Flip item and person
      result[item][person]=prefs[person][item]
  return result

# %%
items = transformPrefs(critics)
pprint(items)
pprint(myTopMatches(items))
pprint(getRecommendations(items,'Just My Luck'))
# Out:
# {'Just My Luck': {'Claudia Puig': 3.0,
#                   'Gene Seymour': 1.5,
#                   'Lisa Rose': 3.0,
#                   'Mick LaSalle': 2.0},
#  'Lady in the Water': {'Gene Seymour': 3.0,
#                        'Jack Matthews': 3.0,
#                        'Lisa Rose': 2.5,
#                        'Michael Phillips': 2.5,
#                        'Mick LaSalle': 3.0},
#  'Snakes on a Plane': {'Claudia Puig': 3.5,
#                        'Gene Seymour': 3.5,
#                        'Jack Matthews': 4.0,
#                        'Lisa Rose': 3.5,
#                        'Michael Phillips': 3.0,
#                        'Mick LaSalle': 4.0,
#                        'Toby': 4.5},
#  'Superman Returns': {'Claudia Puig': 4.0,
#                       'Gene Seymour': 5.0,
#                       'Jack Matthews': 5.0,
#                       'Lisa Rose': 3.5,
#                       'Michael Phillips': 3.5,
#                       'Mick LaSalle': 3.0,
#                       'Toby': 4.0},
#  'The Night Listener': {'Claudia Puig': 4.5,
#                         'Gene Seymour': 3.0,
#                         'Jack Matthews': 3.0,
#                         'Lisa Rose': 3.0,
#                         'Michael Phillips': 4.0,
#                         'Mick LaSalle': 3.0},
#  'You, Me and Dupree': {'Claudia Puig': 2.5,
#                         'Gene Seymour': 3.5,
#                         'Jack Matthews': 3.5,
#                         'Lisa Rose': 2.5,
#                         'Mick LaSalle': 2.0,
#                         'Toby': 1.0}}
# [('Lady in the Water and Snakes on a Plane', 0.7637626158259785),
#  ('You, Me and Dupree and Superman Returns', 0.6579516949597695),
#  ('Just My Luck and The Night Listener', 0.5555555555555556),
#  ('Superman Returns and Lady in the Water', 0.4879500364742689),
#  ('You, Me and Dupree and Lady in the Water', 0.3333333333333333),
#  ('Superman Returns and Snakes on a Plane', 0.11180339887498941),
#  ('Superman Returns and The Night Listener', -0.1798471947990544),
#  ('You, Me and Dupree and The Night Listener', -0.250000000000002),
#  ('Just My Luck and Snakes on a Plane', -0.3333333333333333),
#  ('Just My Luck and Superman Returns', -0.42289003161103106),
#  ('Just My Luck and You, Me and Dupree', -0.4856618642571827),
#  ('The Night Listener and Snakes on a Plane', -0.5663521139548527),
#  ('Lady in the Water and The Night Listener', -0.6123724356957927),
#  ('You, Me and Dupree and Snakes on a Plane', -0.6454972243679047),
#  ('Just My Luck and Lady in the Water', -0.9449111825230676)]
# [('Michael Phillips', 4.0), ('Jack Matthews', 3.0)]

# %% [markdown]
# #### https://github.com/pcao10/pydelicious/issues/43

# %%
from pydelicious import get_popular,get_userposts,get_urlposts
import time

def initializeUserDict(tag,count=5):
  user_dict={}
  # get the top count' popular posts
  for p1 in get_popular(tag=tag)[0:count]:
    # find all users who posted this
    for p2 in get_urlposts(p1['href']):
      user=p2['user']
      user_dict[user]={}
  return user_dict

def fillItems(user_dict):
  all_items={}
  # Find links posted by all users
  for user in user_dict:
    for i in range(3):
      try:
        posts=get_userposts(user)
        break
      except:
        print ("Failed user "+user+", retrying")
        time.sleep(4)
    for post in posts:
      url=post['href']
      user_dict[user][url]=1.0
      all_items[url]=1
  
  # Fill in missing items with 0
  for ratings in user_dict.values():
    for item in all_items:
      if item not in ratings:
        ratings[item]=0.0

# %%
# delusers = initializeUserDict('programming')
# delusers['tsegaran']={}
# fillItems(delusers)

# %%
# get_popular(tag='programming')[:10]

# %% [markdown]
# ## 基于物品的过滤

# %%
def calculateSimilarItems(prefs,n=10):
  # Create a dictionary of items showing which other items they
  # are most similar to.
  result={}
  # Invert the preference matrix to be item-centric
  itemPrefs=transformPrefs(prefs)
  c=0
  for item in itemPrefs:
    # Status updates for large datasets
    c+=1
    if c%100==0: 
        print ("%d / %d" % (c,len(itemPrefs)))
    # Find the most similar items to this one
    scores=topMatches(itemPrefs,item,n=n,similarity=sim_distance)
    result[item]=scores
  return result

# %%
itemsim=calculateSimilarItems(critics)
pprint(itemsim)
# Out:
# {'Just My Luck': [(0.2222222222222222, 'Lady in the Water'),
#                   (0.18181818181818182, 'You, Me and Dupree'),
#                   (0.15384615384615385, 'The Night Listener'),
#                   (0.10526315789473684, 'Snakes on a Plane'),
#                   (0.06451612903225806, 'Superman Returns')],
#  'Lady in the Water': [(0.4, 'You, Me and Dupree'),
#                        (0.2857142857142857, 'The Night Listener'),
#                        (0.2222222222222222, 'Snakes on a Plane'),
#                        (0.2222222222222222, 'Just My Luck'),
#                        (0.09090909090909091, 'Superman Returns')],
#  'Snakes on a Plane': [(0.2222222222222222, 'Lady in the Water'),
#                        (0.18181818181818182, 'The Night Listener'),
#                        (0.16666666666666666, 'Superman Returns'),
#                        (0.10526315789473684, 'Just My Luck'),
#                        (0.05128205128205128, 'You, Me and Dupree')],
#  'Superman Returns': [(0.16666666666666666, 'Snakes on a Plane'),
#                       (0.10256410256410256, 'The Night Listener'),
#                       (0.09090909090909091, 'Lady in the Water'),
#                       (0.06451612903225806, 'Just My Luck'),
#                       (0.05333333333333334, 'You, Me and Dupree')],
#  'The Night Listener': [(0.2857142857142857, 'Lady in the Water'),
#                         (0.18181818181818182, 'Snakes on a Plane'),
#                         (0.15384615384615385, 'Just My Luck'),
#                         (0.14814814814814814, 'You, Me and Dupree'),
#                         (0.10256410256410256, 'Superman Returns')],
#  'You, Me and Dupree': [(0.4, 'Lady in the Water'),
#                         (0.18181818181818182, 'Just My Luck'),
#                         (0.14814814814814814, 'The Night Listener'),
#                         (0.05333333333333334, 'Superman Returns'),
#                         (0.05128205128205128, 'Snakes on a Plane')]}

# %%
def getRecommendedItems(prefs,itemMatch,user):
  userRatings=prefs[user]
  scores={}
  totalSim={}
  # Loop over items rated by this user
  for (item,rating) in userRatings.items( ):

    # Loop over items similar to this one
    for (similarity,item2) in itemMatch[item]:

      # Ignore if this user has already rated this item
      if item2 in userRatings: continue
      # Weighted sum of rating times similarity
      scores.setdefault(item2,0)
      scores[item2]+=similarity*rating
      # Sum of all the similarities
      totalSim.setdefault(item2,0)
      totalSim[item2]+=similarity

  # Divide each total score by total weighting to get an average
  rankings=[(score/totalSim[item],item) for item,score in scores.items( )]

  # Return the rankings from highest to lowest
  rankings.sort( )
  rankings.reverse( )
  return rankings

# %%
getRecommendedItems(critics,itemsim,'Toby')
# Out:
# [(3.182634730538922, 'The Night Listener'),
#  (2.5983318700614575, 'Just My Luck'),
#  (2.4730878186968837, 'Lady in the Water')]

# %%
critics
# Out:
# {'Claudia Puig': {'Just My Luck': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 4.0,
#   'The Night Listener': 4.5,
#   'You, Me and Dupree': 2.5},
#  'Gene Seymour': {'Just My Luck': 1.5,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Jack Matthews': {'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Lisa Rose': {'Just My Luck': 3.0,
#   'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 3.5,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 2.5},
#  'Michael Phillips': {'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.0,
#   'Superman Returns': 3.5,
#   'The Night Listener': 4.0},
#  'Mick LaSalle': {'Just My Luck': 2.0,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 3.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 2.0},
#  'Toby': {'Snakes on a Plane': 4.5,
#   'Superman Returns': 4.0,
#   'You, Me and Dupree': 1.0}}

# %% [markdown]
# ## 使用MovieLens数据集

# %%
def loadMovieLens(path='data/movielens'):
  # Get movie titles
  movies={}
  # ingnore
  for line in open(path+'/u.item',errors='ignore'):
    (id,title)=line.split('|')[0:2]
    movies[id]=title
  
  # Load data
  prefs={}
  for line in open(path+'/u.data'):
    (user,movieid,rating,ts)=line.split('\t')
    prefs.setdefault(user,{})
    prefs[user][movies[movieid]]=float(rating)
  return prefs

# %%
prefs=loadMovieLens()
getRecommendations(prefs,'87')
# Out:
# [('unknown', 3.541386439780948),
#  ('Zeus and Roxanne (1997)', 2.206510468856659),
#  ("Young Poisoner's Handbook, The (1995)", 3.3819077059083824),
#  ('You So Crazy (1994)', 3.0000000000000004),
#  ('Year of the Horse (1997)', 2.0052819344400112),
#  ('Yankee Zulu (1994)', 1.0),
#  ('Wrong Trousers, The (1993)', 4.463287461290221),
#  ('World of Apu, The (Apur Sansar) (1959)', 4.177871176381616),
#  ("Wooden Man's Bride, The (Wu Kui) (1994)", 2.25602297941656),
#  ('Wonderland (1997)', 3.3117604632609665),
#  ('Wonderful, Horrible Life of Leni Riefenstahl, The (1993)',
#   4.14590252004904),
#  ('Women, The (1939)', 3.6135928801753763),
#  ('Woman in Question, The (1950)', 1.0),
#  ('Wolf (1994)', 2.7204784550506167),
#  ('Witness (1985)', 4.0),
#  ('Withnail and I (1987)', 3.542764908918436),
#  ('With Honors (1994)', 3.0330851077633376),
#  ('Wishmaster (1997)', 2.35572879338577),
#  ('Winter Guest, The (1997)', 2.855705393098161),
#  ('Winnie the Pooh and the Blustery Day (1968)', 3.9281109691491984),
#  ('Wings of the Dove, The (1997)', 3.7393515394067145),
#  ('Wings of Desire (1987)', 3.8971079453172677),
#  ('Wings of Courage (1995)', 4.0),
#  ('Window to Paris (1994)', 4.0),
#  ('Willy Wonka and the Chocolate Factory (1971)', 3.612751543873164),
#  ("William Shakespeare's Romeo and Juliet (1996)", 3.606721497895801),
#  ('Wild Things (1998)', 3.0744248513311487),
#  ('Wild Reeds (1994)', 2.8124685080637515),
#  ('Wild Bunch, The (1969)', 3.8524084317047818),
#  ('Wild Bill (1995)', 2.4216550900284552),
#  ('Wild America (1997)', 2.9016818571309635),
#  ('Wife, The (1995)', 3.0),
#  ("Widows' Peak (1994)", 3.488247562470869),
#  ('Whole Wide World, The (1996)', 4.004432142207875),
#  ('White Squall (1996)', 3.4593556032434702),
#  ("White Man's Burden (1995)", 1.9485170940829055),
#  ('White Balloon, The (1995)', 2.383985861240904),
#  ('When the Cats Away (Chacun cherche son chat) (1996)', 3.3943767460041245),
#  ('When a Man Loves a Woman (1994)', 3.47219192283593),
#  ('When We Were Kings (1996)', 4.266002300110169),
#  ('When Night Is Falling (1995)', 3.314583188489196),
#  ("What's Love Got to Do with It (1993)", 3.5138526869410986),
#  ("What's Eating Gilbert Grape (1993)", 3.50507394127549),
#  ('What Happened Was... (1994)', 2.388196696988663),
#  ("Wes Craven's New Nightmare (1994)", 3.054457148035265),
#  ("Wend Kuuni (God's Gift) (1982)", 1.0),
#  ('Welcome to the Dollhouse (1995)', 3.4954077114728648),
#  ('Welcome To Sarajevo (1997)', 3.5623178654083874),
#  ('Wedding Singer, The (1998)', 3.360539404238621),
#  ('Wedding Gift, The (1994)', 4.4148707845920745),
#  ('Wedding Bell Blues (1996)', 3.0),
#  ('Washington Square (1997)', 3.29909844518376),
#  ('Warriors of Virtue (1997)', 2.9479293110307916),
#  ('War, The (1994)', 3.2967478479298107),
#  ('War at Home, The (1996)', 2.0),
#  ('War Room, The (1993)', 3.6027438378311407),
#  ('Wallace & Gromit: The Best of Aardman Animation (1996)', 4.485151301801341),
#  ('Walking and Talking (1996)', 4.025981399746679),
#  ('Walking Dead, The (1995)', 2.155780299355793),
#  ('Walkabout (1971)', 3.7730065028169206),
#  ('Walk in the Sun, A (1945)', 3.0000000000000004),
#  ('Walk in the Clouds, A (1995)', 3.3802680471816484),
#  ('Waiting to Exhale (1995)', 2.8625367790073133),
#  ('Waiting for Guffman (1996)', 4.125839287139456),
#  ('Wag the Dog (1997)', 3.524496541894027),
#  ('Volcano (1997)', 2.783528645225168),
#  ('Visitors, The (Visiteurs, Les) (1993)', 2.930837498623245),
#  ('Virtuosity (1995)', 2.8228770798803566),
#  ('Village of the Damned (1995)', 2.7281062259819198),
#  ('Vie est belle, La (Life is Rosey) (1987)', 1.0),
#  ('Very Natural Thing, A (1974)', 1.0),
#  ('Very Brady Sequel, A (1996)', 2.2898985708716233),
#  ('Vertigo (1958)', 4.236305631536013),
#  ('Vermont Is For Lovers (1992)', 1.0),
#  ('Vermin (1998)', 1.267142072038529),
#  ('Venice/Venice (1992)', 1.0),
#  ('Vanya on 42nd Street (1994)', 3.3592657531047463),
#  ('Van, The (1996)', 2.411462555403671),
#  ('Vampire in Brooklyn (1995)', 1.909069096859679),
#  ('Usual Suspects, The (1995)', 4.431079071179522),
#  ('Up Close and Personal (1996)', 3.317257523816152),
#  ('Unzipped (1995)', 3.8583139093865015),
#  ('Until the End of the World (Bis ans Ende der Welt) (1991)',
#   2.8583075272189413),
#  ('Unstrung Heroes (1995)', 3.3616881332783453),
#  ('Unhook the Stars (1996)', 2.785759692693944),
#  ('Unforgiven (1992)', 3.9147194090689736),
#  ('Unforgettable (1996)', 3.254715623278702),
#  ('Underworld (1997)', 2.651193022246857),
#  ('Underneath, The (1995)', 2.3326030700817344),
#  ('Underground (1995)', 2.5492252712035186),
#  ('Under Siege 2: Dark Territory (1995)', 2.495761640115283),
#  ('Unbearable Lightness of Being, The (1988)', 3.2956200409711576),
#  ('Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)',
#   3.9292796584154464),
#  ('U.S. Marshalls (1998)', 3.176108801401202),
#  ('U Turn (1997)', 3.1964471018165153),
#  ('Two or Three Things I Know About Her (1966)', 3.1406321238354997),
#  ('Two if by Sea (1996)', 2.410025844998328),
#  ('Two Much (1996)', 2.1572154912477983),
#  ('Two Friends (1986) ', 3.0),
#  ('Two Deaths (1995)', 2.048893494282224),
#  ('Two Bits (1995)', 1.7539222088707327),
#  ('Twisted (1996)', 2.9999999999999996),
#  ('Twin Town (1997)', 1.6253927168234326),
#  ('Twilight (1998)', 2.5127052462600967),
#  ('Twelfth Night (1996)', 3.4005758406839908),
#  ('Turning, The (1992)', 2.7237647822125033),
#  ('Turbulence (1997)', 2.6026457914374355),
#  ('Turbo: A Power Rangers Movie (1997)', 1.0),
#  ('Truth or Consequences, N.M. (1997)', 1.7335637675139353),
#  ('Trust (1990)', 3.493701395367203),
#  ('Truman Show, The (1998)', 1.6496605662389987),
#  ('True Romance (1993)', 3.5962460166280685),
#  ('True Crime (1995)', 3.3348449350974336),
#  ('Trigger Effect, The (1996)', 3.238131063961253),
#  ('Trial by Jury (1994)', 2.4102851120684967),
#  ('Trial and Error (1997)', 2.568349081612586),
#  ('Trees Lounge (1996)', 3.1485565912053706),
#  ('Traveller (1997)', 3.4787681700700928),
#  ('Transformers: The Movie, The (1986)', 2.793345817149875),
#  ('Trainspotting (1996)', 3.8435113347933205),
#  ('Toy Story (1995)', 3.913678684602598),
#  ('Touki Bouki (Journey of the Hyena) (1973)', 1.0),
#  ('Tough and Deadly (1995)', 1.0032100594548383),
#  ('Touch of Evil (1958)', 3.947701894565157),
#  ('Touch (1997)', 2.645096897806466),
#  ('Total Eclipse (1995)', 2.1860696356505183),
#  ('Top Hat (1935)', 3.7746253140142545),
#  ('Tomorrow Never Dies (1997)', 3.490028889941741),
#  ('Tombstone (1993)', 3.648247640625183),
#  ('Tom and Huck (1995)', 3.157750560405908),
#  ('Tom & Viv (1994)', 2.559258277119574),
#  ('Tokyo Fist (1995)', 4.0),
#  ('To Live (Huozhe) (1994)', 3.339909495585274),
#  ('To Have, or Not (1995)', 1.79366111365693),
#  ('To Gillian on Her 37th Birthday (1996)', 2.94133871924308),
#  ('To Cross the Rubicon (1991)', 1.0),
#  ('To Catch a Thief (1955)', 4.093104101816696),
#  ('To Be or Not to Be (1942)', 3.544274455728754),
#  ('Titanic (1997)', 4.327626892682978),
#  ('Tin Men (1987)', 3.034223989847155),
#  ('Tin Drum, The (Blechtrommel, Die) (1979)', 3.6242717870455303),
#  ('Tin Cup (1996)', 3.223502697058319),
#  ('Timecop (1994)', 3.0259910637649936),
#  ('Time to Kill, A (1996)', 3.6778842939060388),
#  ('Time Tracers (1995)', 1.7373380301902428),
#  ('Tigrero: A Film That Was Never Made (1994)', 1.0),
#  ('Tie That Binds, The (1995)', 2.2725918229162407),
#  ('Tie Me Up! Tie Me Down! (1990)', 3.1554090982762877),
#  ('Threesome (1994)', 2.9638281912863267),
#  ('Three Wishes (1995)', 3.361386744377759),
#  ('Three Musketeers, The (1993)', 3.3741723693799535),
#  ('Three Lives and Only One Death (1996)', 3.0),
#  ('Three Colors: White (1994)', 3.8876873131041845),
#  ('Three Colors: Red (1994)', 4.008212423331544),
#  ('Three Colors: Blue (1993)', 3.905788524248479),
#  ('Three Caballeros, The (1945)', 3.2523063078589156),
#  ('Thousand Acres, A (1997)', 3.4602833100203187),
#  ('Thirty-Two Short Films About Glenn Gould (1993)', 3.9621301458386373),
#  ('Third Man, The (1949)', 4.28102577621743),
#  ('Thinner (1996)', 2.453572565979413),
#  ("Things to Do in Denver when You're Dead (1995)", 3.156324679217707),
#  ('Thin Man, The (1934)', 4.112332101486153),
#  ('Thin Line Between Love and Hate, A (1996)', 2.4644724830270297),
#  ('Thin Blue Line, The (1988)', 3.8122874469200765),
#  ('Thieves (Voleurs, Les) (1996)', 4.015448853389668),
#  ('They Made Me a Criminal (1939)', 5.0),
#  ('Theodore Rex (1995)', 1.4543585289768381),
#  ('The Innocent (1994)', 2.881665288482612),
#  ('The Deadly Cure (1996)', 1.0),
#  ('The Courtyard (1995)', 1.0),
#  ('That Darn Cat! (1997)', 2.019196093204636),
#  ('That Darn Cat! (1965)', 2.850310949750445),
#  ('Tetsuo II: Body Hammer (1992)', 2.268953622778375),
#  ('Terror in a Texas Town (1958)', 1.0),
#  ('Terminal Velocity (1994)', 2.727686934567342),
#  ('Temptress Moon (Feng Yue) (1996)', 1.0),
#  ('Telling Lies in America (1997)', 3.1490525818765587),
#  ('Taxi Driver (1976)', 3.9686746636299928),
#  ('Target (1995)', 3.0),
#  ('Tank Girl (1995)', 2.6802873551226245),
#  ('Tango Lesson, The (1997)', 3.8029246523769746),
#  ('Talking About Sex (1994)', 1.6940636268605964),
#  ('Tales from the Hood (1995)', 2.0586737357345686),
#  ('Tales from the Crypt Presents: Bordello of Blood (1996)',
#   2.553113459437725),
#  ('Tales From the Crypt Presents: Demon Knight (1995)', 2.746775301615412),
#  ('Tainted (1998)', 3.0),
#  ('T-Men (1947)', 1.0),
#  ('Symphonie pastorale, La (1946)', 1.0),
#  ('Sword in the Stone, The (1963)', 3.3817582827587556),
#  ('Switchback (1997)', 3.1819462647805468),
#  ('Swiss Family Robinson (1960)', 3.401465086400724),
#  ('Swingers (1996)', 3.8512515434919012),
#  ('Swept from the Sea (1997)', 1.488105499247275),
#  ('Sweet Nothing (1995)', 3.0),
#  ('Sweet Hereafter, The (1997)', 3.699674956644546),
#  ('Swan Princess, The (1994)', 2.8466377326018515),
#  ('Suture (1993)', 1.4142461477004755),
#  ('Surviving the Game (1994)', 2.390769600147242),
#  ('Surviving Picasso (1996)', 2.9799298135326775),
#  ('Super Mario Bros. (1993)', 2.0430583569796714),
#  ('Sunset Park (1996)', 2.3538902390853305),
#  ('Sunset Blvd. (1950)', 4.075726908484637),
#  ('Sunchaser, The (1996)', 2.9999999999999996),
#  ('Sum of Us, The (1994)', 3.725242231339885),
#  ('Sudden Manhattan (1996)', 1.655313527586403),
#  ('Sudden Death (1995)', 2.6562555716240204),
#  ('Substitute, The (1996)', 2.616062972543825),
#  ('Substance of Fire, The (1996)', 3.206816070363126),
#  ('SubUrbia (1997)', 3.3605132678640146),
#  ('Stupids, The (1996)', 1.7107091456544012),
#  ('Stuart Saves His Family (1995)', 1.9458291229698217),
#  ('Stripes (1981)', 4.062850463028377),
#  ('Striking Distance (1993)', 2.4207884902173187),
#  ('Streetcar Named Desire, A (1951)', 3.789674823196093),
#  ('Street Fighter (1994)', 2.3608545386422986),
#  ('Strawberry and Chocolate (Fresa y chocolate) (1993)', 3.600128167222597),
#  ('Stranger, The (1994)', 2.7553718665344133),
#  ('Stranger in the House (1997)', 1.717301303828269),
#  ('Story of Xinghua, The (1993)', 3.1629888077037767),
#  ('Stonewall (1995)', 4.0),
#  ("Stephen King's The Langoliers (1995)", 2.3635452895686657),
#  ('Stefano Quantestorie (1993)', 1.0),
#  ('Steel (1997)', 1.6890513328358434),
#  ('Stealing Beauty (1996)', 3.151119117922968),
#  ('Steal Big, Steal Little (1995)', 2.593276415307633),
#  ('Starship Troopers (1997)', 3.3015150767246277),
#  ('Stars Fell on Henrietta, The (1995)', 1.3597939263305374),
#  ('Star Trek: Generations (1994)', 3.4459486812305564),
#  ('Star Trek VI: The Undiscovered Country (1991)', 3.37433784565593),
#  ('Star Trek V: The Final Frontier (1989)', 2.3830516372469916),
#  ('Star Maps (1997)', 3.1930789620764592),
#  ("Star Maker, The (Uomo delle stelle, L') (1995)", 2.6932846315785826),
#  ('Star Kid (1997)', 5.0),
#  ('Stand by Me (1986)', 3.8502059745434702),
#  ('Stalker (1979)', 3.5831781902799986),
#  ('Stalingrad (1993)', 3.0668100858595726),
#  ('Stag (1997)', 1.812764924319433),
#  ('Squeeze (1996)', 1.3873144868287248),
#  ('Spy Hard (1996)', 2.387014012804537),
#  ('Sprung (1997)', 2.0),
#  ('Spitfire Grill, The (1996)', 3.7831605728808118),
#  ('Spirits of the Dead (Tre passi nel delirio) (1968)', 2.328675048441847),
#  ('Spice World (1997)', 1.635367865224971),
#  ('Sphere (1998)', 3.2041515565797565),
#  ('Spellbound (1945)', 3.944366139364596),
#  ('Species (1995)', 2.887676720291258),
#  ('Specialist, The (1994)', 2.157193635252498),
#  ('Spawn (1997)', 2.634751639579586),
#  ('Spanking the Monkey (1994)', 2.880242662745658),
#  ('Spanish Prisoner, The (1997)', 4.0),
#  ('Space Jam (1996)', 2.7345048968379864),
#  ('Sound of Music, The (1965)', 3.8682875471692304),
#  ('Soul Food (1997)', 3.0843928044583966),
#  ("Sophie's Choice (1982)", 3.8451637948824806),
#  ('Somewhere in Time (1980)', 3.5415319276286414),
#  ('Somebody to Love (1994)', 1.0),
#  ("Some Mother's Son (1996)", 4.282525635314467),
#  ('Some Like It Hot (1959)', 4.0131253691296624),
#  ('Some Kind of Wonderful (1987)', 3.705784486799867),
#  ('Some Folks Call It a Sling Blade (1993)', 4.339023302721376),
#  ('Solo (1996)', 1.7740514348849485),
#  ('So Dear to My Heart (1949)', 3.215566786094301),
#  ('Snow White and the Seven Dwarfs (1937)', 3.7681769087793935),
#  ('Smoke (1995)', 3.568351916988035),
#  ("Smilla's Sense of Snow (1997)", 3.152250509155278),
#  ('Smile Like Yours, A (1997)', 2.4207227285289874),
#  ('Small Faces (1995)', 2.0),
#  ('Sliver (1993)', 2.3573350092409733),
#  ('Slingshot, The (1993)', 3.305072580833213),
#  ('Sling Blade (1996)', 4.127713893237545),
#  ('Sliding Doors (1998)', 3.4478492811663233),
#  ('Sleepover (1995)', 3.0),
#  ('Sixth Man, The (1997)', 3.3620049008526283),
#  ('Six Degrees of Separation (1993)', 3.661833200472692),
#  ('Sirens (1994)', 3.042199605631189),
#  ('Simple Wish, A (1997)', 1.5176814486999683),
#  ('Simple Twist of Fate, A (1994)', 3.131353193424044),
#  ('Silence of the Palace, The (Saimt el Qusur) (1994)', 3.0),
#  ('Silence of the Lambs, The (1991)', 4.32933764565644),
#  ('Showgirls (1995)', 1.668070284399904),
#  ('Show, The (1995)', 2.9344007695395224),
#  ('Short Cuts (1993)', 3.785546371494124),
#  ('Shopping (1994)', 2.0),
#  ('Shooting Fish (1997)', 2.173314355256029),
#  ('Shooter, The (1995)', 1.7987554268985713),
#  ('Shining, The (1980)', 3.7435998203241545),
#  ('Shine (1996)', 4.050432986233937),
#  ('Shiloh (1997)', 3.0156055843815732),
#  ("She's the One (1996)", 2.9731496943551528),
#  ("She's So Lovely (1997)", 2.6303246268490454),
#  ('Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)', 3.6463908480095752),
#  ('Shallow Grave (1994)', 3.775867925758357),
#  ('Shall We Dance? (1996)', 4.226995188612443),
#  ('Shall We Dance? (1937)', 3.901166125975079),
#  ('Shaggy Dog, The (1959)', 2.9890642910214575),
#  ('Shadows (Cienie) (1988)', 1.0),
#  ('Shadowlands (1993)', 4.048173278650087),
#  ('Shadow of Angels (Schatten der Engel) (1976)', 1.0),
#  ('Shadow Conspiracy (1997)', 2.9693415184072323),
#  ('Sgt. Bilko (1996)', 2.6061319432276893),
#  ('Sexual Life of the Belgians, The (1994)', 1.4518804231041644),
#  ('Sex, Lies, and Videotape (1989)', 3.399260449398669),
#  ('Seventh Seal, The (Sjunde inseglet, Det) (1957)', 3.5107883818561927),
#  ('Seven Years in Tibet (1997)', 3.5559851970055023),
#  ('Seven (Se7en) (1995)', 3.8857573829068692),
#  ('Set It Off (1996)', 3.217510786815282),
#  ('Senseless (1998)', 1.5790602543340009),
#  ('Sense and Sensibility (1995)', 3.977918993572899),
#  ('Selena (1997)', 3.4242685026228674),
#  ('Secrets & Lies (1996)', 4.184987403056227),
#  ('Secret of Roan Inish, The (1994)', 3.83138416405016),
#  ('Secret Garden, The (1993)', 3.636541341327574),
#  ('Secret Agent, The (1996)', 2.8659991391520454),
#  ('Secret Adventures of Tom Thumb, The (1993)', 2.3700832860799665),
#  ('Second Jungle Book: Mowgli & Baloo, The (1997)', 1.7755708819179918),
#  ('Search for One-eye Jimmy, The (1996)', 1.308868926983452),
#  ('Screamers (1995)', 2.63648291175833),
#  ('Scream of Stone (Schrei aus Stein) (1991)', 3.0),
#  ('Scream 2 (1997)', 3.000098221465666),
#  ('Scream (1996)', 3.409069541087804),
#  ('Scout, The (1994)', 2.6418892506107867),
#  ('Schizopolis (1996)', 3.0349456523142457),
#  ('Scarlet Letter, The (1995)', 2.3035940045590015),
#  ('Scarlet Letter, The (1926)', 2.9404583935143505),
#  ('Savage Nights (Nuits fauves, Les) (1992)', 3.467371058091731),
#  ('Santa with Muscles (1996)', 5.0),
#  ('Salut cousin! (1996)', 1.79366111365693),
#  ('Saint, The (1997)', 3.139660917079344),
#  ('Saint of Fort Washington, The (1993)', 5.0),
#  ('Safe Passage (1994)', 3.4858271237735687),
#  ('Safe (1995)', 3.736509503626157),
#  ('Sabrina (1954)', 3.9413245187166357),
#  ('S.F.W. (1994)', 2.001878189351941),
#  ('Run of the Country, The (1995)', 2.7319915205444),
#  ('Rumble in the Bronx (1995)', 3.4029089040900744),
#  ('Ruling Class, The (1972)', 3.7666725338967812),
#  ('Rudy (1993)', 3.389747672694995),
#  ('Ruby in Paradise (1993)', 3.073884443277885),
#  ('Rough Magic (1995)', 2.2208975858495346),
#  ('Rosewood (1997)', 3.6953671480762527),
#  ('Rosencrantz and Guildenstern Are Dead (1990)', 3.8228072460975846),
#  ("Roseanna's Grave (For Roseanna) (1997)", 2.1358429351905386),
#  ('Roommates (1995)', 3.03823833434473),
#  ('Room with a View, A (1986)', 3.9407376050425635),
#  ("Romy and Michele's High School Reunion (1997)", 3.021633446564445),
#  ('Romper Stomper (1992)', 2.2389606347441564),
#  ('Romeo Is Bleeding (1993)', 2.982345021484112),
#  ('Roman Holiday (1953)', 4.25850762549531),
#  ('Rocket Man (1997)', 2.2826079624646924),
#  ('Rock, The (1996)', 3.7736156233020077),
#  ('Robocop 3 (1993)', 1.6572637541418258),
#  ('Robin Hood: Prince of Thieves (1991)', 3.180576515325452),
#  ('Robin Hood: Men in Tights (1993)', 2.5428304174587226),
#  ("Robert A. Heinlein's The Puppet Masters (1994)", 2.9050510468344766),
#  ('Rob Roy (1995)', 3.524058191721859),
#  ('Road to Wellville, The (1994)', 2.147100024383966),
#  ('Rising Sun (1993)', 2.964357400318489),
#  ('Ripe (1996)', 2.0),
#  ('Right Stuff, The (1983)', 3.971775949917249),
#  ('Ridicule (1996)', 3.5802941314993233),
#  ('Richie Rich (1994)', 2.3651288646406208),
#  ('Richard III (1995)', 3.546902167566959),
#  ("Rich Man's Wife, The (1996)", 2.2549346954085494),
#  ('Rhyme & Reason (1997)', 1.929069189361806),
#  ('Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)',
#   3.7940108116840685),
#  ('Restoration (1995)', 3.3197194353078343),
#  ('Reservoir Dogs (1992)', 3.9612158467397727),
#  ('Replacement Killers, The (1998)', 3.427818261618898),
#  ('Rent-a-Kid (1995)', 2.8320351946454725),
#  ('Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)', 3.0),
#  ('Remains of the Day, The (1993)', 3.723175923288419),
#  ('Relic, The (1997)', 2.8993947128272874),
#  ('Relative Fear (1994)', 1.0),
#  ('Ref, The (1994)', 3.044204342502664),
#  ('Red Rock West (1992)', 3.6444113302980576),
#  ('Red Firecracker, Green Firecracker (1994)', 3.15454379356603),
#  ('Red Corner (1997)', 3.4807390352602208),
#  ('Reckless (1995)', 2.580227125682381),
#  ('Rebel Without a Cause (1955)', 3.8364945013593417),
#  ('Rebecca (1940)', 3.989969213128826),
#  ('Rear Window (1954)', 4.3430036727045405),
#  ('Real Genius (1985)', 3.6811971051754844),
#  ('Ready to Wear (Pret-A-Porter) (1994)', 1.5509452880447432),
#  ('Raw Deal (1948)', 2.0),
#  ('Ransom (1996)', 3.6264257331713257),
#  ('Ran (1985)', 4.065281747988819),
#  ('Raise the Red Lantern (1991)', 4.056929689294367),
#  ('Rainmaker, The (1997)', 3.5134378955461134),
#  ('Radioland Murders (1994)', 3.35372429631265),
#  ('Race the Sun (1996)', 2.667970992333587),
#  ('Quiz Show (1994)', 3.664790055926244),
#  ('Quiet Room, The (1996)', 4.357499994134492),
#  ('Quick and the Dead, The (1995)', 3.185972694402831),
#  ('Quest, The (1996)', 2.32659183081882),
#  ('Queen Margot (Reine Margot, La) (1994)', 3.473236508693324),
#  ('Quartier Mozart (1992)', 1.0),
#  ('Pushing Hands (1992)', 1.543493142171638),
#  ('Purple Noon (1960)', 2.7895916038150217),
#  ('Pump Up the Volume (1990)', 3.362954959613479),
#  ('Psycho (1960)', 3.9812271988854926),
#  ('Prophecy, The (1995)', 2.9805453990331605),
#  ('Prophecy II, The (1998)', 2.8097705151978882),
#  ('Promise, The (Versprechen, Das) (1994)', 1.0),
#  ('Promesse, La (1996)', 3.0513480245960176),
#  ('Private Parts (1997)', 3.473920482123661),
#  ('Prisoner of the Mountains (Kavkazsky Plennik) (1996)', 3.291955847836465),
#  ('Princess Caraboo (1994)', 3.1305168925632096),
#  ('Princess Bride, The (1987)', 4.278477087434079),
#  ('Primary Colors (1998)', 4.072673862090624),
#  ('Primal Fear (1996)', 3.63371241623368),
#  ('Priest (1994)', 4.0910068812274725),
#  ('Price Above Rubies, A (1998)', 3.0),
#  ('Pretty Woman (1990)', 3.5076539390850474),
#  ("Preacher's Wife, The (1996)", 2.7965500139081176),
#  ('Power 98 (1995)', 1.0),
#  ('Powder (1995)', 3.290195274491894),
#  ('Postman, The (1997)', 3.2303323522187593),
#  ('Postino, Il (1994)', 3.9906641614487213),
#  ('Portrait of a Lady, The (1996)', 2.5158781078578154),
#  ('Ponette (1996)', 3.5043397421632103),
#  ('Pompatus of Love, The (1996)', 2.7963046510079885),
#  ('Pollyanna (1960)', 3.165104329917034),
#  ('Police Story 4: Project S (Chao ji ji hua) (1993)', 1.0),
#  ('Poison Ivy II (1995)', 2.043215942674063),
#  ('Poetic Justice (1993)', 2.805563019347164),
#  ('Pocahontas (1995)', 2.5122220734113156),
#  ('Playing God (1997)', 2.463980443059929),
#  ('Pinocchio (1940)', 3.775616441451026),
#  ('Pink Floyd - The Wall (1982)', 3.3107988319617485),
#  ('Pillow Book, The (1995)', 3.694728167521219),
#  ('Pie in the Sky (1995)', 1.6530500169035363),
#  ('Picture Perfect (1997)', 3.0441580098621133),
#  ('Picture Bride (1995)', 3.351996163667899),
#  ('Picnic (1955)', 3.7875305235038743),
#  ('Piano, The (1993)', 3.5228192242211374),
#  ('Philadelphia Story, The (1940)', 4.246061867924133),
#  ('Philadelphia (1993)', 3.914968395146884),
#  ('Phenomenon (1996)', 3.5693345233295135),
#  ('Phat Beach (1996)', 1.206021752814521),
#  ("Pharaoh's Army (1995)", 1.0),
#  ('Phantoms (1998)', 2.300227112917891),
#  ('Phantom, The (1996)', 2.478053762121346),
#  ("Pete's Dragon (1977)", 2.866978947223325),
#  ('Pest, The (1997)', 1.4276697760657298),
#  ('Persuasion (1995)', 3.9032811107688508),
#  ('Perfect World, A (1993)', 3.714952286619563),
#  ('Perfect Candidate, A (1996)', 3.842113101458371),
#  ('Perez Family, The (1995)', 2.524379289863755),
#  ('People vs. Larry Flynt, The (1996)', 3.5439887729661557),
#  ('Penny Serenade (1941)', 2.899061766222454),
#  ('Peacemaker, The (1997)', 3.1440469665613824),
#  ('Patton (1970)', 4.10309515040582),
#  ('Paths of Glory (1957)', 4.0967451142221885),
#  ('Pather Panchali (1955)', 4.696244466490867),
#  ('Passion Fish (1992)', 3.094870993533425),
#  ('Party Girl (1995)', 2.462990787754407),
#  ('Paris, Texas (1984)', 3.33595780531742),
#  ('Paris, France (1993)', 1.9083004982964955),
#  ('Paris Was a Woman (1995)', 3.0),
#  ('Paris Is Burning (1990)', 3.740826952523237),
#  ('Parent Trap, The (1961)', 3.209519594928518),
#  ('Paradise Road (1997)', 3.5985084258954823),
#  ('Paradise Lost: The Child Murders at Robin Hood Hills (1996)',
#   3.902375052811796),
#  ('Paper, The (1994)', 3.1776278670847216),
#  ('Panther (1995)', 2.5095661731519754),
#  ('Palookaville (1996)', 2.62822230837312),
#  ('Palmetto (1998)', 3.842494321904452),
#  ('Pallbearer, The (1996)', 2.081492120184097),
#  ('Pagemaster, The (1994)', 2.274837450553624),
#  ('Outlaw, The (1943)', 2.5031737832005856),
#  ('Outbreak (1995)', 3.3520670633563148),
#  ('Out to Sea (1997)', 2.779069894653373),
#  ('Other Voices, Other Rooms (1997)', 2.9999999999999996),
#  ('Othello (1995)', 3.561618104557797),
#  ('Oscar & Lucinda (1997)', 3.6965260846522474),
#  ('Orlando (1993)', 3.4708110668031433),
#  ('Original Gangstas (1996)', 2.020003106889123),
#  ('Operation Dumbo Drop (1995)', 2.533349159014434),
#  ('Open Season (1996)', 1.0016247844387558),
#  ('Only You (1994)', 3.3443191617033445),
#  ('One Night Stand (1997)', 3.2709042867665206),
#  ("One Flew Over the Cuckoo's Nest (1975)", 4.298358088701394),
#  ('One Fine Day (1996)', 3.142169946389951),
#  ('Once Were Warriors (1994)', 4.082479894359185),
#  ('Once Upon a Time... When We Were Colored (1995)', 3.1767790932340016),
#  ('Once Upon a Time in the West (1969)', 3.733105574989043),
#  ('Once Upon a Time in America (1984)', 3.3194442561107347),
#  ('On Golden Pond (1981)', 3.5989199301025874),
#  ('Omen, The (1976)', 3.386516889571886),
#  ('Oliver & Company (1988)', 2.859592024962049),
#  ('Old Yeller (1957)', 3.548797941636097),
#  ('Old Man and the Sea, The (1958)', 3.529073146621729),
#  ('Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)',
#   2.55468841962095),
#  ('Office Killer (1997)', 1.0),
#  ('Of Love and Shadows (1994)', 2.0035504188858972),
#  ('Of Human Bondage (1934)', 3.7275625716544143),
#  ('Object of My Affection, The (1998)', 4.0),
#  ('Nowhere (1997)', 2.0),
#  ('Now and Then (1995)', 3.6645063418315242),
#  ('Notorious (1946)', 4.218755646142777),
#  ('Nothing to Lose (1994)', 3.29501538596202),
#  ('Nothing Personal (1995)', 2.0),
#  ('Nosferatu a Venezia (1986)', 2.07031606191775),
#  ('Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)',
#   3.2490769021825257),
#  ('North by Northwest (1959)', 4.286589850363965),
#  ('North (1994)', 2.5307938275648705),
#  ('Normal Life (1996)', 3.0),
#  ("Nobody's Fool (1994)", 3.4819239396909687),
#  ('Nobody Loves Me (Keiner liebt mich) (1994)', 1.0),
#  ('No Escape (1994)', 2.3060351561378907),
#  ('Nnette et Boni (1996)', 3.639754654054236),
#  ('Nixon (1995)', 2.8748371346556842),
#  ('Ninotchka (1939)', 3.712050109405825),
#  ('Nina Takes a Lover (1994)', 2.878752583903044),
#  ('Nil By Mouth (1997)', 1.3833160066284538),
#  ('Nikita (La Femme Nikita) (1990)', 4.025763525880345),
#  ('Nightwatch (1997)', 3.455805401610608),
#  ('Nightmare on Elm Street, A (1984)', 3.15461270421491),
#  ('Nightmare Before Christmas, The (1993)', 3.4356689600025785),
#  ('Night on Earth (1991)', 3.515805552501727),
#  ('Night of the Living Dead (1968)', 3.2524690463709645),
#  ('Night Flier (1997)', 3.8308596288183026),
#  ('Night Falls on Manhattan (1997)', 3.3531185914942863),
#  ('Nico Icon (1995)', 3.0),
#  ('Nick of Time (1995)', 3.0386876167830814),
#  ('Niagara, Niagara (1997)', 2.0),
#  ('Next Step, The (1995)', 3.0),
#  ('Next Karate Kid, The (1994)', 2.2960011915534104),
#  ('Newton Boys, The (1998)', 3.435926345297073),
#  ('New York Cop (1996)', 2.630565905860665),
#  ('New Jersey Drive (1995)', 3.0283719796715767),
#  ('New Age, The (1994)', 1.0),
#  ('NeverEnding Story III, The (1994)', 2.2146231255927686),
#  ('Neon Bible, The (1995)', 1.2299182411411802),
#  ('Nemesis 2: Nebula (1995)', 2.0),
#  ('Nelly & Monsieur Arnaud (1995)', 3.5352183959924472),
#  ('Nell (1994)', 3.5095545777999355),
#  ('Natural Born Killers (1994)', 2.797238540034816),
#  ("National Lampoon's Senior Trip (1995)", 2.031184822163154),
#  ('Naked in New York (1994)', 1.3515590208103962),
#  ('Naked (1993)', 3.146586111519385),
#  ('Nadja (1994)', 1.9324882369723562),
#  ('Mystery Science Theater 3000: The Movie (1996)', 3.502917944489668),
#  ('My Own Private Idaho (1991)', 3.5773433422423406),
#  ('My Man Godfrey (1936)', 4.039029471522834),
#  ('My Life as a Dog (Mitt liv som hund) (1985)', 4.0599558183709465),
#  ("My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)",
#   1.1887897965458425),
#  ('My Left Foot (1989)', 3.82757042265281),
#  ('My Fellow Americans (1996)', 3.2189486152936007),
#  ('My Favorite Season (1993)', 3.0),
#  ('My Family (1995)', 3.7045080398065102),
#  ('My Fair Lady (1964)', 3.7475847230011965),
#  ('My Crazy Life (Mi vida loca) (1993)', 2.9128497953479364),
#  ("My Best Friend's Wedding (1997)", 3.4144675295809774),
#  ('Mute Witness (1994)', 2.929798911984891),
#  ("Muriel's Wedding (1994)", 3.5671088742034764),
#  ('Murder, My Sweet (1944)', 3.844352037598853),
#  ('Murder in the First (1995)', 3.546173882063498),
#  ('Murder at 1600 (1997)', 3.048269638072623),
#  ('Mulholland Falls (1996)', 2.894361090664227),
#  ('Much Ado About Nothing (1993)', 4.140560165818704),
#  ('Mrs. Winterbourne (1996)', 3.156606066626855),
#  ('Mrs. Parker and the Vicious Circle (1994)', 3.3685383238567983),
#  ('Mrs. Dalloway (1997)', 4.535081339106104),
#  ('Mrs. Brown (Her Majesty, Mrs. Brown) (1997)', 3.9801755163139125),
#  ('Mr. Wrong (1996)', 2.0985095356131023),
#  ('Mr. Wonderful (1993)', 2.9999999999999996),
#  ('Mr. Smith Goes to Washington (1939)', 4.111774432357194),
#  ('Mr. Magoo (1997)', 2.64929922831517),
#  ('Mr. Jones (1993)', 2.7524488196209966),
#  ("Mr. Holland's Opus (1995)", 3.777686915471535),
#  ('Mouse Hunt (1997)', 2.7221738841242087),
#  ('Mother Night (1996)', 3.2191627016642763),
#  ('Mostro, Il (1994)', 1.0),
#  ('Mortal Kombat: Annihilation (1997)', 2.015677897888812),
#  ('Mortal Kombat (1995)', 2.831679221010283),
#  ('Moonlight and Valentino (1995)', 2.6373983859634937),
#  ('Monty Python and the Holy Grail (1974)', 4.055125029942256),
#  ('Month by the Lake, A (1995)', 3.219882297832354),
#  ('Money Train (1995)', 2.5714617434087272),
#  ('Money Talks (1997)', 2.6723783247585775),
#  ('Mondo (1996)', 3.085709553101),
#  ('Moll Flanders (1996)', 3.4306693091283256),
#  ('Modern Affair, A (1995)', 1.0),
#  ('Mixed Nuts (1994)', 2.4063836067308033),
#  ('Misrables, Les (1995)', 3.6944422897100218),
#  ('Mirror Has Two Faces, The (1996)', 3.3303582614362917),
#  ('Mirage (1995)', 3.0),
#  ('Miracle on 34th Street (1994)', 3.904598176902956),
#  ('Mina Tannenbaum (1994)', 2.7825650235236465),
#  ('Mimic (1997)', 2.7693965553927646),
#  ("Miller's Crossing (1990)", 3.6517539066965514),
#  ('Mille bolle blu (1993)', 1.0),
#  ('Mighty, The (1998)', 1.0),
#  ('Mighty Morphin Power Rangers: The Movie (1995)', 2.4423111502424155),
#  ('Midnight in the Garden of Good and Evil (1997)', 3.2364354987691297),
#  ('Midnight Dancers (Sibak) (1994)', 2.5128385669465216),
#  ("Microcosmos: Le peuple de l'herbe (1996)", 3.151085566469935),
#  ('Michael Collins (1996)', 3.5637242763789105),
#  ('Miami Rhapsody (1995)', 2.4418862291832513),
#  ('Metro (1997)', 2.718051762297737),
#  ('Metisse (Caf au Lait) (1993)', 2.2417351011483304),
#  ('Mercury Rising (1998)', 3.324438150013565),
#  ('Menace II Society (1993)', 3.4114116681538795),
#  ('Men in Black (1997)', 3.8100818945749286),
#  ('Men With Guns (1997)', 3.3258032601583523),
#  ('Meet Wally Sparks (1997)', 1.6510621985793847),
#  ('Meet Me in St. Louis (1944)', 3.379073287601775),
#  ('Meet John Doe (1941)', 4.137097913340735),
#  ('Mediterraneo (1991)', 3.8175388328030877),
#  ("McHale's Navy (1997)", 2.1741975584080016),
#  ('Maybe, Maybe Not (Bewegte Mann, Der) (1994)', 3.1954481659242315),
#  ('Maya Lin: A Strong Clear Vision (1994)', 4.427520682864959),
#  ('Maximum Risk (1996)', 2.7348783664990854),
#  ('MatchMaker, The (1997)', 2.9580201953304166),
#  ("Mary Shelley's Frankenstein (1994)", 3.0584021846635485),
#  ('Mary Reilly (1996)', 2.7371487998971293),
#  ('Mary Poppins (1964)', 3.7760446859364847),
#  ("Marvin's Room (1996)", 3.3799627735961804),
#  ('Marlene Dietrich: Shadow and Light (1996) ', 5.0),
#  ('Marked for Death (1990)', 2.2398574821017245),
#  ('Mark of Zorro, The (1940)', 3.5650831163912002),
#  ("Margaret's Museum (1995)", 3.634806575616388),
#  ('Manon of the Spring (Manon des sources) (1986)', 4.082735075991782),
#  ('Manny & Lo (1996)', 2.8375116057170677),
#  ('Manhattan Murder Mystery (1993)', 3.67229903710187),
#  ('Manhattan (1979)', 3.5365183693332547),
#  ('Man of the Year (1995)', 3.0462973313617807),
#  ('Man of No Importance, A (1994)', 3.516798943194201),
#  ('Man in the Iron Mask, The (1998)', 3.530899373274027),
#  ('Man from Down Under, The (1943)', 1.0),
#  ('Man Without a Face, The (1993)', 3.4666725583042877),
#  ('Man Who Would Be King, The (1975)', 4.102660919591605),
#  ('Man Who Knew Too Little, The (1997)', 2.9492684630495787),
#  ('Maltese Falcon, The (1941)', 4.154664534250202),
#  ('Mallrats (1995)', 3.4879443803519745),
#  ('Malice (1993)', 3.194882527531995),
#  ('Magic Hour, The (1998)', 1.9712352414890426),
#  ('Madonna: Truth or Dare (1991)', 2.2377349160676094),
#  ('Madness of King George, The (1994)', 3.7590830743724086),
#  ('Made in America (1993)', 2.4891253167098393),
#  ('Madame Butterfly (1995)', 3.420917425740325),
#  ('Mad Love (1995)', 2.1478155959860326),
#  ('Mad Dog Time (1996)', 3.0),
#  ('Mad City (1997)', 3.097871863783811),
#  ('Machine, The (1994)', 1.4479890833607505),
#  ('Ma vie en rose (My Life in Pink) (1997)', 3.921542364950151),
#  ('MURDER and murder (1996)', 2.0),
#  ('M. Butterfly (1993)', 3.5346880508837994),
#  ('M (1931)', 3.87150796685633),
#  ('Low Life, The (1994)', 1.0),
#  ("Lover's Knot (1996)", 1.6276379218690389),
#  ('Love! Valour! Compassion! (1997)', 3.6353507666551788),
#  ('Love in the Afternoon (1957)', 4.248002679842592),
#  ('Love and a .45 (1994)', 2.8162989957715836),
#  ('Love and Other Catastrophes (1996)', 2.563056503687783),
#  ('Love and Death on Long Island (1997)', 1.6933418341566158),
#  ('Love Serenade (1996)', 3.4539414469386442),
#  ('Love Jones (1997)', 3.2808698359746247),
#  ('Love Is All There Is (1996)', 3.0),
#  ('Love Bug, The (1969)', 2.916697002012123),
#  ('Love Affair (1994)', 2.868222511533281),
#  ('Love & Human Remains (1993)', 2.830541397895877),
#  ('Lotto Land (1995)', 1.0),
#  ('Lost in Space (1998)', 3.239960320949827),
#  ('Lost Horizon (1937)', 3.9381979934043785),
#  ('Lost Highway (1997)', 2.951906234480416),
#  ('Losing Isaiah (1995)', 3.0555407637576724),
#  ('Losing Chase (1996)', 2.6254547181128736),
#  ('Lord of Illusions (1995)', 2.3928241395758),
#  ('Looking for Richard (1996)', 3.5865135571143383),
#  ('Long Kiss Goodnight, The (1996)', 3.443073020215626),
#  ('Lone Star (1996)', 4.030788986733014),
#  ('Locusts, The (1997)', 1.4958930233469367),
#  ('Loch Ness (1995)', 2.788952811842392),
#  ('Local Hero (1983)', 3.9155584990512553),
#  ('Loaded (1994)', 2.1958518543794385),
#  ('Living in Oblivion (1995)', 3.4545314846821933),
#  ('Live Nude Girls (1995)', 3.0053192427208675),
#  ('Little Women (1994)', 3.696855156993344),
#  ('Little Rascals, The (1994)', 2.8090385430061886),
#  ('Little Princess, The (1939)', 3.7362425915048263),
#  ('Little Princess, A (1995)', 3.6968178233462177),
#  ('Little Odessa (1994)', 2.522882859128989),
#  ('Little Lord Fauntleroy (1936)', 3.1119797395151383),
#  ('Little Buddha (1993)', 3.3573958217125335),
#  ('Little Big League (1994)', 2.858469189219595),
#  ('Lion King, The (1994)', 3.8567717348688695),
#  ('Line King: Al Hirschfeld, The (1996)', 3.9976114341417297),
#  ('Like Water For Chocolate (Como agua para chocolate) (1992)',
#   3.798474423767782),
#  ('Life with Mikey (1993)', 2.141445126788975),
#  ('Life Less Ordinary, A (1997)', 3.2731748775773504),
#  ('Liebelei (1933)', 1.0),
#  ('Liar Liar (1997)', 3.2094914455824837),
#  ('Letter From Death Row, A (1998)', 4.815019082242709),
#  ('Leopard Son, The (1996)', 1.0),
#  ('Legends of the Fall (1994)', 3.4358657325268918),
#  ('Legal Deceit (1997)', 4.89884443128923),
#  ('Leaving Las Vegas (1995)', 3.718046615457772),
#  ('Leave It to Beaver (1997)', 1.7950906600463241),
#  ('Leading Man, The (1996)', 4.538723693474813),
#  ('Lay of the Land, The (1997)', 1.6909780003544805),
#  ('Lawrence of Arabia (1962)', 4.286491737536518),
#  ('Lawnmower Man, The (1992)', 2.492699331631972),
#  ('Lawnmower Man 2: Beyond Cyberspace (1996)', 1.8535779975974467),
#  ('Laura (1944)', 4.0659019484206285),
#  ('Late Bloomers (1996)', 3.212454772416945),
#  ('Last of the Mohicans, The (1992)', 3.68606283897206),
#  ('Last Time I Saw Paris, The (1954)', 3.596136756496497),
#  ('Last Time I Committed Suicide, The (1997)', 2.3844351463259676),
#  ('Last Supper, The (1995)', 3.3808285458741416),
#  ('Last Summer in the Hamptons (1995)', 2.3472128759231605),
#  ('Last Man Standing (1996)', 2.6768887306839892),
#  ('Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995)',
#   2.934136323811792),
#  ('Last Dance (1996)', 2.9097837497792383),
#  ('Last Action Hero (1993)', 2.7378683342849564),
#  ('Lassie (1994)', 1.9455505244071136),
#  ('Lashou shentan (1992)', 1.0),
#  ('Larger Than Life (1996)', 2.210908311168898),
#  ('Land and Freedom (Tierra y libertad) (1995)', 3.0),
#  ('Land Before Time III: The Time of the Great Giving (1995) (V)',
#   1.8527358202244897),
#  ('Lamerica (1994)', 4.652397061026758),
#  ('Ladybird Ladybird (1994)', 2.6874510341204685),
#  ('Lady of Burlesque (1943)', 4.0),
#  ('L.A. Confidential (1997)', 4.138231949463648),
#  ('Kundun (1997)', 3.918039577282884),
#  ('Kull the Conqueror (1997)', 2.5228665078927053),
#  ('Koyaanisqatsi (1983)', 3.229018246745879),
#  ('Kolya (1996)', 3.8936968836931825),
#  ('Kissed (1996)', 3.1013688598614393),
#  ('Kiss the Girls (1997)', 3.4821707086313625),
#  ('Kiss of Death (1995)', 2.8593365266677706),
#  ('Kiss Me, Guido (1997)', 3.3534760084823074),
#  ('King of the Hill (1993)', 3.2130684465327386),
#  ('King of New York (1990)', 1.0),
#  ('Kim (1950)', 3.244973944550882),
#  ('Killing Zoe (1994)', 3.4748158498862467),
#  ('Killing Fields, The (1984)', 4.174229853929806),
#  ('Killer: A Journal of Murder (1995)', 4.0),
#  ('Killer (Bulletproof Heart) (1994)', 2.4898793452452366),
#  ('Kika (1993)', 2.0),
#  ('Kids in the Hall: Brain Candy (1996)', 3.069539334520299),
#  ('Kids (1995)', 2.953087585148865),
#  ("Kid in King Arthur's Court, A (1995)", 2.7060553440291524),
#  ('Kicking and Screaming (1995)', 2.9722385384292114),
#  ('Kicked in the Head (1997)', 2.0672013439706762),
#  ('Keys to Tulsa (1997)', 2.182982501933898),
#  ('Kazaam (1996)', 1.6608289373588534),
#  ('Kaspar Hauser (1993)', 4.450979436941035),
#  ('Kansas City (1996)', 2.060436700385745),
#  ('Kama Sutra: A Tale of Love (1996)', 3.491847578069313),
#  ('Kalifornia (1993)', 3.1991639857133527),
#  ('Just Cause (1995)', 3.1376753994641824),
#  ('Jury Duty (1995)', 2.1302419765100558),
#  ('Juror, The (1996)', 2.8752807600026613),
#  ("Jupiter's Wife (1994)", 4.0),
#  ('Jungle2Jungle (1997)', 2.494349212811966),
#  ('Jungle Book, The (1994)', 3.4770929409379248),
#  ('Jumanji (1995)', 3.404650037351105),
#  ('Judgment Night (1993)', 2.673429420963372),
#  ('Judge Dredd (1995)', 2.7851548666024253),
#  ('Jude (1996)', 2.962555817172522),
#  ('Joy Luck Club, The (1993)', 3.7115001045161207),
#  ('Journey of August King, The (1995)', 1.6210341304549167),
#  ('Johns (1996)', 3.0),
#  ('Johnny Mnemonic (1995)', 2.6005048460743954),
#  ('Johnny 100 Pesos (1993)', 1.511535956615462),
#  ('Jingle All the Way (1996)', 1.9011385793419249),
#  ('Jerry Maguire (1996)', 3.7501429632716325),
#  ('Jerky Boys, The (1994)', 2.756110778547383),
#  ('Jefferson in Paris (1995)', 1.7422377378930418),
#  ('Jean de Florette (1986)', 4.066927237985946),
#  ('Jaws 3-D (1983)', 2.00653292975618),
#  ('Jaws 2 (1978)', 2.6829348268756523),
#  ('Jaws (1975)', 3.8142929748715155),
#  ("Jason's Lyric (1994)", 3.0120504457047317),
#  ('Jane Eyre (1996)', 3.256134370936468),
#  ('James and the Giant Peach (1996)', 2.957438679271525),
#  ('Jade (1995)', 2.1370285687477257),
#  ("Jackie Chan's First Strike (1996)", 3.2827281416687066),
#  ('Jackie Brown (1997)', 3.664292324581927),
#  ('Jackal, The (1997)', 3.069443514934652),
#  ('Jack and Sarah (1995)', 2.1078845967896824),
#  ('JLG/JLG - autoportrait de dcembre (1994)', 1.0),
#  ("It's My Party (1995)", 3.1795367699948467),
#  ('It Takes Two (1995)', 2.741299400073628),
#  ('It Happened One Night (1934)', 4.007467738445042),
#  ('It Could Happen to You (1994)', 3.8171519844687833),
#  ('Island of Dr. Moreau, The (1996)', 2.1946969219497445),
#  ('Invitation, The (Zaproszenie) (1986)', 1.0),
#  ('Inventing the Abbotts (1997)', 3.2907746180782462),
#  ('Intimate Relations (1996)', 3.0),
#  ('Interview with the Vampire (1994)', 3.124061891294844),
#  ('Inspector General, The (1949)', 4.013693746400131),
#  ('Innocents, The (1961)', 4.532337612572981),
#  ('Innocent Sleep, The (1995)', 1.5488782671334103),
#  ('Infinity (1996)', 2.5526092562275964),
#  ('Indian in the Cupboard, The (1995)', 2.865887444586191),
#  ('Indian Summer (1996)', 2.860195093783861),
#  ('Incognito (1997)', 4.019175272923253),
#  ('In the Realm of the Senses (Ai no corrida) (1976)', 1.8626664418664127),
#  ('In the Name of the Father (1993)', 3.820630429037278),
#  ('In the Mouth of Madness (1995)', 2.781280641539254),
#  ('In the Line of Duty 2 (1987)', 2.3685453474710205),
#  ('In the Company of Men (1997)', 3.631554527185179),
#  ('In the Bleak Midwinter (1995)', 3.295969076709056),
#  ('In Love and War (1996)', 3.2070131047469213),
#  ('In & Out (1997)', 3.3084776209178073),
#  ('Immortal Beloved (1994)', 3.4421635831992816),
#  ('Ill Gotten Gains (1997)', 3.0),
#  ('If Lucy Fell (1996)', 2.6145399594202496),
#  ('Ice Storm, The (1997)', 3.530515415681743),
#  ('I, Worst of All (Yo, la peor de todas) (1990)', 1.0),
#  ("I'm Not Rappaport (1996)", 2.9199351159391504),
#  ("I'll Do Anything (1994)", 2.8150248443294674),
#  ('I Shot Andy Warhol (1996)', 3.2107179626715063),
#  ('I Like It Like That (1994)', 2.2217349503557244),
#  ('I Know What You Did Last Summer (1997)', 2.996199848944731),
#  ("I Don't Want to Talk About It (De eso no se habla) (1993)", 4.0),
#  ("I Can't Sleep (J'ai pas sommeil) (1994)", 2.3331481533795095),
#  ('Hush (1998)', 2.0),
#  ('Hurricane Streets (1998)', 2.2036302425773364),
#  ('Hunted, The (1995)', 1.8935821200416074),
#  ('Hunt for Red October, The (1990)', 3.9940924931756867),
#  ('Hungarian Fairy Tale, A (1987)', 1.0),
#  ('Hunchback of Notre Dame, The (1996)', 3.265866627434105),
#  ('Hugo Pool (1997)', 1.0),
#  ('Hudsucker Proxy, The (1994)', 3.514896501198256),
#  ('Howling, The (1981)', 2.899428493765745),
#  ('How to Make an American Quilt (1995)', 3.257185105267344),
#  ('How to Be a Player (1997)', 2.368035310798748),
#  ('Houseguest (1994)', 2.8471371366057965),
#  ('House of the Spirits, The (1993)', 2.992153061861851),
#  ('House of Yes, The (1997)', 3.049408515560158),
#  ('House Party 3 (1994)', 1.736463076296376),
#  ('Hour of the Pig, The (1993)', 3.440973234251102),
#  ('Hotel de Love (1996)', 3.059113723014347),
#  ('Hostile Intentions (1994)', 1.0),
#  ('Horseman on the Roof, The (Hussard sur le toit, Le) (1995)',
#   4.254367528648984),
#  ('Horse Whisperer, The (1998)', 2.510415985786592),
#  ('Hoodlum (1997)', 2.809178759087307),
#  ('Homeward Bound: The Incredible Journey (1993)', 3.121914206589404),
#  ('Homeward Bound II: Lost in San Francisco (1996)', 2.5580219066318532),
#  ('Home for the Holidays (1995)', 3.0297540673504195),
#  ('Home Alone 3 (1997)', 1.7487472199550835),
#  ('Homage (1995)', 1.0),
#  ('Hollow Reed (1996)', 2.183255627381715),
#  ('His Girl Friday (1940)', 4.016115732215095),
#  ('Highlander III: The Sorcerer (1994)', 2.231266877954908),
#  ('Highlander (1986)', 3.675663843737697),
#  ('Higher Learning (1995)', 3.33637820762967),
#  ('High School High (1996)', 2.5256615993550553),
#  ('High Noon (1952)', 4.07359744151194),
#  ('Hideaway (1995)', 2.1792185741357),
#  ('Here Comes Cookie (1935)', 2.0),
#  ('Hercules (1997)', 3.440963661634902),
#  ('Herbie Rides Again (1974)', 2.274511274515924),
#  ('Henry V (1989)', 4.132967379933907),
#  ('Hellraiser: Bloodline (1996)', 2.2334404509052526),
#  ('Heidi Fleiss: Hollywood Madam (1995) ', 2.1159306838100336),
#  ('Hedd Wyn (1992)', 1.0),
#  ('Heavyweights (1994)', 2.1467744248220186),
#  ('Heavy Metal (1981)', 3.260462664241684),
#  ('Heavy (1995)', 2.998437806833446),
#  ('Heavenly Creatures (1994)', 3.305621752613758),
#  ("Heaven's Prisoners (1996)", 2.2447002969158616),
#  ('Heaven & Earth (1993)', 2.5600652019396994),
#  ('Hearts and Minds (1996)', 4.7321082983941425),
#  ('Hear My Song (1991)', 2.848387665636749),
#  ('Head Above Water (1996)', 3.2041993036892302),
#  ('He Walked by Night (1948)', 4.0),
#  ('Haunted World of Edward D. Wood Jr., The (1995)', 3.896194749619128),
#  ('Hate (Haine, La) (1995)', 3.0604836246695477),
#  ('Harriet the Spy (1996)', 2.564971685174104),
#  ('Harold and Maude (1971)', 3.8050019755622486),
#  ('Harlem (1993)', 3.2455449769581124),
#  ('Hard Rain (1998)', 3.0686324329594066),
#  ('Hard Eight (1996)', 4.083952259129651),
#  ('Happy Gilmore (1996)', 3.380993602030624),
#  ('Hana-bi (1997)', 3.0),
#  ('Hamlet (1996)', 4.042986925756751),
#  ('Halloween: The Curse of Michael Myers (1995)', 2.1077020938914517),
#  ('Half Baked (1998)', 2.3413260304971946),
#  ('Hackers (1995)', 2.669824795228837),
#  ('Gumby: The Movie (1995)', 2.6916647671254994),
#  ('Guilty as Sin (1993)', 2.092696830382346),
#  ('Guantanamera (1994)', 3.271496544763906),
#  ('Grosse Pointe Blank (1997)', 3.6821818312287387),
#  ('Grosse Fatigue (1994)', 1.515912312674566),
#  ('Grifters, The (1990)', 3.323101554362145),
#  ("Gridlock'd (1997)", 2.8382764696092675),
#  ('Great Race, The (1965)', 3.411162640395323),
#  ('Great Expectations (1998)', 3.3079155467451273),
#  ('Great Escape, The (1963)', 4.232538099223533),
#  ('Great Dictator, The (1940)', 3.917437973770977),
#  ('Great Day in Harlem, A (1994)', 5.0),
#  ('Grease 2 (1982)', 2.1407385371243217),
#  ('Grateful Dead (1995)', 3.262497361843616),
#  ('Grass Harp, The (1995)', 2.933029639019473),
#  ('Grand Day Out, A (1992)', 3.9907767359713886),
#  ('Graduate, The (1967)', 4.08890372271623),
#  ('Grace of My Heart (1996)', 3.274180436026805),
#  ('Gordy (1995)', 1.0),
#  ('Goofy Movie, A (1995)', 2.623554725911556),
#  ('Good Will Hunting (1997)', 4.376071110447773),
#  ('Good Morning (1971)', 1.0),
#  ('Good Man in Africa, A (1994)', 3.052389301373806),
#  ('Gone with the Wind (1939)', 3.9553891734614304),
#  ("Gone Fishin' (1997)", 2.0741155917385568),
#  ('Golden Earrings (1947)', 4.1404051355160405),
#  ('Gold Diggers: The Secret of Bear Mountain (1995)', 2.9846802435340614),
#  ('Godfather: Part II, The (1974)', 4.2046213473545695),
#  ('Go Fish (1994)', 3.286959688977861),
#  ('Glimmer Man, The (1996)', 2.6545108339307806),
#  ('Glengarry Glen Ross (1992)', 3.287277197672253),
#  ('Glass Shield, The (1994)', 1.9344007695395222),
#  ('Girls Town (1996)', 3.0),
#  ('Girl in the Cadillac (1995)', 1.0),
#  ('Girl 6 (1996)', 2.601313916417312),
#  ("Gilligan's Island: The Movie (1998)", 1.0263042782599605),
#  ('Gigi (1958)', 3.666218817350175),
#  ('Giant (1956)', 3.8246153268735834),
#  ('Ghosts of Mississippi (1996)', 3.592774073586035),
#  ('Ghost in the Shell (Kokaku kidotai) (1995)', 3.596892002566514),
#  ('Ghost and the Darkness, The (1996)', 3.264166384152715),
#  ('Ghost and Mrs. Muir, The (1947)', 3.6292919473669896),
#  ('Ghost (1990)', 3.529723400410539),
#  ('Getting Even with Dad (1994)', 1.5414896344490316),
#  ('Getting Away With Murder (1996)', 1.0),
#  ('Getaway, The (1994)', 2.369968037384042),
#  ('Get on the Bus (1996)', 3.3656767989269087),
#  ('Geronimo: An American Legend (1993)', 3.0528393912870055),
#  ('Germinal (1993)', 2.2500049343522806),
#  ('Georgia (1995)', 3.058972106556165),
#  ('George of the Jungle (1997)', 2.8366292939926114),
#  ('Gay Divorcee, The (1934)', 3.99058651296694),
#  ('Gattaca (1997)', 3.6690173370889116),
#  ('Gate of Heavenly Peace, The (1995)', 4.0),
#  ('Gaslight (1944)', 3.9856647093180935),
#  ('Garden of Finzi-Contini, The (Giardino dei Finzi-Contini, Il) (1970)',
#   4.056113938391495),
#  ('Gang Related (1997)', 2.386875322047713),
#  ('Gandhi (1982)', 4.035998666850938),
#  ('Game, The (1997)', 3.580107977825169),
#  ('Gabbeh (1996)', 2.8864341944823244),
#  ('G.I. Jane (1997)', 3.360599926811047),
#  ('Funny Face (1957)', 3.497763010668676),
#  ('Funeral, The (1996)', 1.9446399819443203),
#  ('Full Speed (1996)', 2.9477896803477313),
#  ('Full Monty, The (1997)', 3.916517707088936),
#  ('From Dusk Till Dawn (1996)', 3.089250618389412),
#  ('Frisk (1995)', 2.0606509225637337),
#  ('Frighteners, The (1996)', 3.2023413396150127),
#  ('Fried Green Tomatoes (1991)', 3.797116707654082),
#  ('Friday (1995)', 3.262276148317411),
#  ('Fresh (1994)', 4.133102599336487),
#  ('French Twist (Gazon maudit) (1995)', 3.085600204643374),
#  ('Freeway (1996)', 3.106611137700377),
#  ('Free Willy 3: The Rescue (1997)', 1.8460836390421103),
#  ('Free Willy 2: The Adventure Home (1995)', 1.9831069263227001),
#  ('Free Willy (1993)', 2.4567195655871448),
#  ('Frankie Starlight (1995)', 2.82384288762781),
#  ('Foxfire (1996)', 2.613597416312458),
#  ('Fox and the Hound, The (1981)', 3.2004916307447195),
#  ('Four Rooms (1995)', 2.9837118145337014),
#  ('Four Days in September (1997)', 4.224125635296416),
#  ('Forrest Gump (1994)', 4.005221741815445),
#  ('Foreign Student (1994)', 2.0),
#  ('Foreign Correspondent (1940)', 3.9167266578235855),
#  ('Forbidden Planet (1956)', 3.816639751870913),
#  ('Forbidden Christ, The (Cristo proibito, Il) (1950)', 2.6639931149351197),
#  ('For the Moment (1994)', 1.3837658692423516),
#  ('For Whom the Bell Tolls (1943)', 4.058995999857309),
#  ('For Richer or Poorer (1997)', 2.297557033640237),
#  ('For Love or Money (1993)', 2.758500635109561),
#  ('For Ever Mozart (1996)', 1.5809717302430872),
#  ('Fools Rush In (1997)', 3.134144797344739),
#  ('Fog, The (1980)', 2.5659450272176323),
#  ('Fly Away Home (1996)', 3.638776875158525),
#  ('Fluke (1995)', 2.41813228270114),
#  ('Flubber (1997)', 2.8376413311121786),
#  ('Flower of My Secret, The (Flor de mi secreto, La) (1995)',
#   2.9636659278168085),
#  ('Flirting With Disaster (1996)', 3.499592355700884),
#  ('Flirt (1995)', 3.465631558990375),
#  ('Flipper (1996)', 1.9924869377133467),
#  ('Flintstones, The (1994)', 2.038907106697679),
#  ('Flesh and Bone (1993)', 2.997046725426813),
#  ('Fled (1996)', 2.560746499911505),
#  ('First Knight (1995)', 2.968925058038452),
#  ('First Kid (1996)', 2.937324416044287),
#  ('Firm, The (1993)', 3.436799865715862),
#  ('Firestorm (1998)', 3.5613149320959447),
#  ('Fire on the Mountain (1996)', 3.0),
#  ('Fire Down Below (1997)', 3.042611700578101),
#  ('Fille seule, La (A Single Girl) (1995)', 3.0),
#  ('Fifth Element, The (1997)', 3.5165337007036506),
#  ('Fierce Creatures (1997)', 3.26700556572142),
#  ('Field of Dreams (1989)', 3.851444376490729),
#  ('Female Perversions (1996)', 2.514395613056117),
#  ('Feeling Minnesota (1996)', 2.5996626987117573),
#  ('Feast of July (1995)', 2.336076552386551),
#  ...]

# %%
itemsim=calculateSimilarItems(prefs,n=50)
getRecommendedItems(prefs,itemsim,'87')[:30]
# Out:
# 100 / 1664
# 200 / 1664
# 300 / 1664
# 400 / 1664
# 500 / 1664
# 600 / 1664
# 700 / 1664
# 800 / 1664
# 900 / 1664
# 1000 / 1664
# 1100 / 1664
# 1200 / 1664
# 1300 / 1664
# 1400 / 1664
# 1500 / 1664
# 1600 / 1664
# [(5.0, "What's Eating Gilbert Grape (1993)"),
#  (5.0, 'Vertigo (1958)'),
#  (5.0, 'Usual Suspects, The (1995)'),
#  (5.0, 'Toy Story (1995)'),
#  (5.0, 'Titanic (1997)'),
#  (5.0, 'Sword in the Stone, The (1963)'),
#  (5.0, 'Stand by Me (1986)'),
#  (5.0, 'Sling Blade (1996)'),
#  (5.0, 'Silence of the Lambs, The (1991)'),
#  (5.0, 'Shining, The (1980)'),
#  (5.0, 'Shine (1996)'),
#  (5.0, 'Sense and Sensibility (1995)'),
#  (5.0, 'Scream (1996)'),
#  (5.0, 'Rumble in the Bronx (1995)'),
#  (5.0, 'Rock, The (1996)'),
#  (5.0, 'Robin Hood: Prince of Thieves (1991)'),
#  (5.0, 'Reservoir Dogs (1992)'),
#  (5.0, 'Police Story 4: Project S (Chao ji ji hua) (1993)'),
#  (5.0, 'House of the Spirits, The (1993)'),
#  (5.0, 'Fresh (1994)'),
#  (5.0, 'Day the Sun Turned Cold, The (Tianguo niezi) (1994)'),
#  (5.0, 'Before the Rain (Pred dozhdot) (1994)'),
#  (5.0, 'Assignment, The (1997)'),
#  (5.0, '1-900 (1994)'),
#  (4.888888888888889, "Ed's Next Move (1996)"),
#  (4.833333333333333, 'Anna (1996)'),
#  (4.8, 'Dark City (1998)'),
#  (4.777777777777778,
#   'Flower of My Secret, The (Flor de mi secreto, La) (1995)'),
#  (4.75, 'Broken English (1996)'),
#  (4.75, ' kldum klaka (Cold Fever) (1994)')]
