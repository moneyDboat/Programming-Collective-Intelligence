# %% [markdown]
# # 提供推荐

# %% [markdown]
# ## 基于用户的协作型过滤
# 核心思想：找出和自己品味相近的一群人

# %%
from pprint import pprint
# A dictionary of movie critics and their ratings of a small
# set of movies
critics={'Lisa Rose': {'Lady in the Water': 2.5, 'Snakes on a Plane': 3.5,
 'Just My Luck': 3.0, 'Superman Returns': 3.5, 'You, Me and Dupree': 2.5, 
 'The Night Listener': 3.0},
'Gene Seymour': {'Lady in the Water': 3.0, 'Snakes on a Plane': 3.5, 
 'Just My Luck': 1.5, 'Superman Returns': 5.0, 'The Night Listener': 3.0, 
 'You, Me and Dupree': 3.5}, 
'Michael Phillips': {'Lady in the Water': 2.5, 'Snakes on a Plane': 3.0,
 'Superman Returns': 3.5, 'The Night Listener': 4.0},
'Claudia Puig': {'Snakes on a Plane': 3.5, 'Just My Luck': 3.0,
 'The Night Listener': 4.5, 'Superman Returns': 4.0, 
 'You, Me and Dupree': 2.5},
'Mick LaSalle': {'Lady in the Water': 3.0, 'Snakes on a Plane': 4.0, 
 'Just My Luck': 2.0, 'Superman Returns': 3.0, 'The Night Listener': 3.0,
 'You, Me and Dupree': 2.0}, 
'Jack Matthews': {'Lady in the Water': 3.0, 'Snakes on a Plane': 4.0,
 'The Night Listener': 3.0, 'Superman Returns': 5.0, 'You, Me and Dupree': 3.5},
'Toby': {'Snakes on a Plane':4.5,'You, Me and Dupree':1.0,'Superman Returns':4.0}}
pprint(critics)
# Out:
# {'Claudia Puig': {'Just My Luck': 3.0,
#                   'Snakes on a Plane': 3.5,
#                   'Superman Returns': 4.0,
#                   'The Night Listener': 4.5,
#                   'You, Me and Dupree': 2.5},
#  'Gene Seymour': {'Just My Luck': 1.5,
#                   'Lady in the Water': 3.0,
#                   'Snakes on a Plane': 3.5,
#                   'Superman Returns': 5.0,
#                   'The Night Listener': 3.0,
#                   'You, Me and Dupree': 3.5},
#  'Jack Matthews': {'Lady in the Water': 3.0,
#                    'Snakes on a Plane': 4.0,
#                    'Superman Returns': 5.0,
#                    'The Night Listener': 3.0,
#                    'You, Me and Dupree': 3.5},
#  'Lisa Rose': {'Just My Luck': 3.0,
#                'Lady in the Water': 2.5,
#                'Snakes on a Plane': 3.5,
#                'Superman Returns': 3.5,
#                'The Night Listener': 3.0,
#                'You, Me and Dupree': 2.5},
#  'Michael Phillips': {'Lady in the Water': 2.5,
#                       'Snakes on a Plane': 3.0,
#                       'Superman Returns': 3.5,
#                       'The Night Listener': 4.0},
#  'Mick LaSalle': {'Just My Luck': 2.0,
#                   'Lady in the Water': 3.0,
#                   'Snakes on a Plane': 4.0,
#                   'Superman Returns': 3.0,
#                   'The Night Listener': 3.0,
#                   'You, Me and Dupree': 2.0},
#  'Toby': {'Snakes on a Plane': 4.5,
#           'Superman Returns': 4.0,
#           'You, Me and Dupree': 1.0}}

# %%
from math import sqrt

# Returns a distance-based similarity score for person1 and person2
def sim_distance(prefs,person1,person2):
  # Get the list of shared_items
  si={}
  for item in prefs[person1]: 
    if item in prefs[person2]: si[item]=1

  # if they have no ratings in common, return 0
  if len(si)==0: return 0

  # Add up the squares of all the differences
  sum_of_squares=sum([pow(prefs[person1][item]-prefs[person2][item],2) 
                      for item in prefs[person1] if item in prefs[person2]])

  return 1/(1+sum_of_squares)

# %%
sim_distance(critics,'Lisa Rose','Gene Seymour')
names = list(critics.keys())
for person1 in names:
    for person2 in names:
        if person1 == person2:
            break
        distance = sim_distance(critics,person1,person2)
        print('%f : %s and %s.' %(distance,person1,person2))
# Out:
# 0.129032 : Mick LaSalle and Gene Seymour.
# 0.133333 : Claudia Puig and Gene Seymour.
# 0.173913 : Claudia Puig and Mick LaSalle.
# 0.148148 : Lisa Rose and Gene Seymour.
# 0.333333 : Lisa Rose and Mick LaSalle.
# 0.285714 : Lisa Rose and Claudia Puig.
# 0.210526 : Michael Phillips and Gene Seymour.
# 0.285714 : Michael Phillips and Mick LaSalle.
# 0.571429 : Michael Phillips and Claudia Puig.
# 0.444444 : Michael Phillips and Lisa Rose.
# 0.800000 : Jack Matthews and Gene Seymour.
# 0.137931 : Jack Matthews and Mick LaSalle.
# 0.181818 : Jack Matthews and Claudia Puig.
# 0.210526 : Jack Matthews and Lisa Rose.
# 0.181818 : Jack Matthews and Michael Phillips.
# 0.108108 : Toby and Gene Seymour.
# 0.307692 : Toby and Mick LaSalle.
# 0.235294 : Toby and Claudia Puig.
# 0.222222 : Toby and Lisa Rose.
# 0.285714 : Toby and Michael Phillips.
# 0.117647 : Toby and Jack Matthews.

# %%
# Returns the Pearson correlation coefficient for p1 and p2
def sim_pearson(prefs,p1,p2):
  # Get the list of mutually rated items
  si={}
  for item in prefs[p1]: 
    if item in prefs[p2]: si[item]=1

  # if they are no ratings in common, return 0
  if len(si)==0: return 0

  # Sum calculations
  n=len(si)
  
  # Sums of all the preferences
  sum1=sum([prefs[p1][it] for it in si])
  sum2=sum([prefs[p2][it] for it in si])
  
  # Sums of the squares
  sum1Sq=sum([pow(prefs[p1][it],2) for it in si])
  sum2Sq=sum([pow(prefs[p2][it],2) for it in si])	
  
  # Sum of the products
  pSum=sum([prefs[p1][it]*prefs[p2][it] for it in si])
  
  # Calculate r (Pearson score)
  num=pSum-(sum1*sum2/n)
  den=sqrt((sum1Sq-pow(sum1,2)/n)*(sum2Sq-pow(sum2,2)/n))
  if den==0: return 0

  r=num/den

  return r

# %%
for person1 in names:
    for person2 in names:
        if person1 == person2:
            break
        distance = sim_pearson(critics,person1,person2)
        print('%f : %s and %s.' %(distance,person1,person2))
# Out:
# 0.411765 : Mick LaSalle and Gene Seymour.
# 0.314970 : Claudia Puig and Gene Seymour.
# 0.566947 : Claudia Puig and Mick LaSalle.
# 0.396059 : Lisa Rose and Gene Seymour.
# 0.594089 : Lisa Rose and Mick LaSalle.
# 0.566947 : Lisa Rose and Claudia Puig.
# 0.204598 : Michael Phillips and Gene Seymour.
# -0.258199 : Michael Phillips and Mick LaSalle.
# 1.000000 : Michael Phillips and Claudia Puig.
# 0.404520 : Michael Phillips and Lisa Rose.
# 0.963796 : Jack Matthews and Gene Seymour.
# 0.211289 : Jack Matthews and Mick LaSalle.
# 0.028571 : Jack Matthews and Claudia Puig.
# 0.747018 : Jack Matthews and Lisa Rose.
# 0.134840 : Jack Matthews and Michael Phillips.
# 0.381246 : Toby and Gene Seymour.
# 0.924473 : Toby and Mick LaSalle.
# 0.893405 : Toby and Claudia Puig.
# 0.991241 : Toby and Lisa Rose.
# -1.000000 : Toby and Michael Phillips.
# 0.662849 : Toby and Jack Matthews.

# %%
# Returns the best matches for person from the prefs dictionary. 
# Number of results and similarity function are optional params.
def topMatches(prefs,person,n=5,similarity=sim_pearson):
  scores=[(similarity(prefs,person,other),other) 
                  for other in prefs if other!=person]
  scores.sort()
  scores.reverse()
  return scores[0:n]

# My own funtion
def myTopMatches(data,similarity=sim_pearson):
    names = list(data.keys())
    results = {}
    
    for person1 in names:
        for person2 in names:
            if person1 == person2:
                break
            results[person1+' and '+person2]=similarity(data,person1,person2)

    #dict sorted by value of key
    return sorted(results.items(),key=lambda d:d[1],reverse=True)

# %%
results = myTopMatches(critics,sim_pearson)
pprint(results)
# Out:
# [('Michael Phillips and Claudia Puig', 1.0),
#  ('Toby and Lisa Rose', 0.9912407071619299),
#  ('Jack Matthews and Gene Seymour', 0.963795681875635),
#  ('Toby and Mick LaSalle', 0.9244734516419049),
#  ('Toby and Claudia Puig', 0.8934051474415647),
#  ('Jack Matthews and Lisa Rose', 0.7470178808339965),
#  ('Toby and Jack Matthews', 0.66284898035987),
#  ('Lisa Rose and Mick LaSalle', 0.5940885257860044),
#  ('Claudia Puig and Mick LaSalle', 0.5669467095138411),
#  ('Lisa Rose and Claudia Puig', 0.5669467095138396),
#  ('Mick LaSalle and Gene Seymour', 0.41176470588235276),
#  ('Michael Phillips and Lisa Rose', 0.40451991747794525),
#  ('Lisa Rose and Gene Seymour', 0.39605901719066977),
#  ('Toby and Gene Seymour', 0.38124642583151164),
#  ('Claudia Puig and Gene Seymour', 0.31497039417435607),
#  ('Jack Matthews and Mick LaSalle', 0.21128856368212925),
#  ('Michael Phillips and Gene Seymour', 0.20459830184114206),
#  ('Jack Matthews and Michael Phillips', 0.13483997249264842),
#  ('Jack Matthews and Claudia Puig', 0.02857142857142857),
#  ('Michael Phillips and Mick LaSalle', -0.2581988897471611),
#  ('Toby and Michael Phillips', -1.0)]

# %%
# Gets recommendations for a person by using a weighted average
# of every other user's rankings
def getRecommendations(prefs,person,similarity=sim_pearson):
  totals={}
  simSums={}
  for other in prefs:
    # don't compare me to myself
    if other==person: continue
    sim=similarity(prefs,person,other)

    # ignore scores of zero or lower
    if sim<=0: continue
    for item in prefs[other]:
  
      # only score movies I haven't seen yet
      if item not in prefs[person] or prefs[person][item]==0:
        # Similarity * Score
        totals.setdefault(item,0)
        totals[item]+=prefs[other][item]*sim
        # Sum of similarities
        simSums.setdefault(item,0)
        simSums[item]+=sim

  # Create the normalized list
  rankings=[(item,total/simSums[item]) for item,total in totals.items()]

  # Return the sorted list
  rankings.sort()
  rankings.reverse()
  return rankings

# %%
getRecommendations(critics,'Toby')
# Out:
# [('The Night Listener', 3.3477895267131013),
#  ('Lady in the Water', 2.832549918264162),
#  ('Just My Luck', 2.5309807037655645)]

# %%
def transformPrefs(prefs):
  result={}
  for person in prefs:
    for item in prefs[person]:
      result.setdefault(item,{})
      
      # Flip item and person
      result[item][person]=prefs[person][item]
  return result

# %%
items = transformPrefs(critics)
pprint(items)
pprint(myTopMatches(items))
pprint(getRecommendations(items,'Just My Luck'))
# Out:
# {'Just My Luck': {'Claudia Puig': 3.0,
#                   'Gene Seymour': 1.5,
#                   'Lisa Rose': 3.0,
#                   'Mick LaSalle': 2.0},
#  'Lady in the Water': {'Gene Seymour': 3.0,
#                        'Jack Matthews': 3.0,
#                        'Lisa Rose': 2.5,
#                        'Michael Phillips': 2.5,
#                        'Mick LaSalle': 3.0},
#  'Snakes on a Plane': {'Claudia Puig': 3.5,
#                        'Gene Seymour': 3.5,
#                        'Jack Matthews': 4.0,
#                        'Lisa Rose': 3.5,
#                        'Michael Phillips': 3.0,
#                        'Mick LaSalle': 4.0,
#                        'Toby': 4.5},
#  'Superman Returns': {'Claudia Puig': 4.0,
#                       'Gene Seymour': 5.0,
#                       'Jack Matthews': 5.0,
#                       'Lisa Rose': 3.5,
#                       'Michael Phillips': 3.5,
#                       'Mick LaSalle': 3.0,
#                       'Toby': 4.0},
#  'The Night Listener': {'Claudia Puig': 4.5,
#                         'Gene Seymour': 3.0,
#                         'Jack Matthews': 3.0,
#                         'Lisa Rose': 3.0,
#                         'Michael Phillips': 4.0,
#                         'Mick LaSalle': 3.0},
#  'You, Me and Dupree': {'Claudia Puig': 2.5,
#                         'Gene Seymour': 3.5,
#                         'Jack Matthews': 3.5,
#                         'Lisa Rose': 2.5,
#                         'Mick LaSalle': 2.0,
#                         'Toby': 1.0}}
# [('Lady in the Water and Snakes on a Plane', 0.7637626158259785),
#  ('You, Me and Dupree and Superman Returns', 0.6579516949597695),
#  ('The Night Listener and Just My Luck', 0.5555555555555556),
#  ('Lady in the Water and Superman Returns', 0.4879500364742689),
#  ('Lady in the Water and You, Me and Dupree', 0.3333333333333333),
#  ('Superman Returns and Snakes on a Plane', 0.11180339887498941),
#  ('The Night Listener and Superman Returns', -0.1798471947990544),
#  ('You, Me and Dupree and The Night Listener', -0.250000000000002),
#  ('Snakes on a Plane and Just My Luck', -0.3333333333333333),
#  ('Superman Returns and Just My Luck', -0.42289003161103106),
#  ('You, Me and Dupree and Just My Luck', -0.4856618642571827),
#  ('The Night Listener and Snakes on a Plane', -0.5663521139548527),
#  ('Lady in the Water and The Night Listener', -0.6123724356957927),
#  ('You, Me and Dupree and Snakes on a Plane', -0.6454972243679047),
#  ('Lady in the Water and Just My Luck', -0.9449111825230676)]
# [('Michael Phillips', 4.0), ('Jack Matthews', 3.0)]

# %% [markdown]
# #### https://github.com/pcao10/pydelicious/issues/43

# %%
from pydelicious import get_popular,get_userposts,get_urlposts
import time

def initializeUserDict(tag,count=5):
  user_dict={}
  # get the top count' popular posts
  for p1 in get_popular(tag=tag)[0:count]:
    # find all users who posted this
    for p2 in get_urlposts(p1['href']):
      user=p2['user']
      user_dict[user]={}
  return user_dict

def fillItems(user_dict):
  all_items={}
  # Find links posted by all users
  for user in user_dict:
    for i in range(3):
      try:
        posts=get_userposts(user)
        break
      except:
        print ("Failed user "+user+", retrying")
        time.sleep(4)
    for post in posts:
      url=post['href']
      user_dict[user][url]=1.0
      all_items[url]=1
  
  # Fill in missing items with 0
  for ratings in user_dict.values():
    for item in all_items:
      if item not in ratings:
        ratings[item]=0.0

# %%
# delusers = initializeUserDict('programming')
# delusers['tsegaran']={}
# fillItems(delusers)

# %%
# get_popular(tag='programming')[:10]

# %% [markdown]
# ## 基于物品的过滤

# %%
def calculateSimilarItems(prefs,n=10):
  # Create a dictionary of items showing which other items they
  # are most similar to.
  result={}
  # Invert the preference matrix to be item-centric
  itemPrefs=transformPrefs(prefs)
  c=0
  for item in itemPrefs:
    # Status updates for large datasets
    c+=1
    if c%100==0: 
        print ("%d / %d" % (c,len(itemPrefs)))
    # Find the most similar items to this one
    scores=topMatches(itemPrefs,item,n=n,similarity=sim_distance)
    result[item]=scores
  return result

# %%
itemsim=calculateSimilarItems(critics)
pprint(itemsim)
# Out:
# {'Just My Luck': [(0.2222222222222222, 'Lady in the Water'),
#                   (0.18181818181818182, 'You, Me and Dupree'),
#                   (0.15384615384615385, 'The Night Listener'),
#                   (0.10526315789473684, 'Snakes on a Plane'),
#                   (0.06451612903225806, 'Superman Returns')],
#  'Lady in the Water': [(0.4, 'You, Me and Dupree'),
#                        (0.2857142857142857, 'The Night Listener'),
#                        (0.2222222222222222, 'Snakes on a Plane'),
#                        (0.2222222222222222, 'Just My Luck'),
#                        (0.09090909090909091, 'Superman Returns')],
#  'Snakes on a Plane': [(0.2222222222222222, 'Lady in the Water'),
#                        (0.18181818181818182, 'The Night Listener'),
#                        (0.16666666666666666, 'Superman Returns'),
#                        (0.10526315789473684, 'Just My Luck'),
#                        (0.05128205128205128, 'You, Me and Dupree')],
#  'Superman Returns': [(0.16666666666666666, 'Snakes on a Plane'),
#                       (0.10256410256410256, 'The Night Listener'),
#                       (0.09090909090909091, 'Lady in the Water'),
#                       (0.06451612903225806, 'Just My Luck'),
#                       (0.05333333333333334, 'You, Me and Dupree')],
#  'The Night Listener': [(0.2857142857142857, 'Lady in the Water'),
#                         (0.18181818181818182, 'Snakes on a Plane'),
#                         (0.15384615384615385, 'Just My Luck'),
#                         (0.14814814814814814, 'You, Me and Dupree'),
#                         (0.10256410256410256, 'Superman Returns')],
#  'You, Me and Dupree': [(0.4, 'Lady in the Water'),
#                         (0.18181818181818182, 'Just My Luck'),
#                         (0.14814814814814814, 'The Night Listener'),
#                         (0.05333333333333334, 'Superman Returns'),
#                         (0.05128205128205128, 'Snakes on a Plane')]}

# %%
def getRecommendedItems(prefs,itemMatch,user):
  userRatings=prefs[user]
  scores={}
  totalSim={}
  # Loop over items rated by this user
  for (item,rating) in userRatings.items( ):

    # Loop over items similar to this one
    for (similarity,item2) in itemMatch[item]:

      # Ignore if this user has already rated this item
      if item2 in userRatings: continue
      # Weighted sum of rating times similarity
      scores.setdefault(item2,0)
      scores[item2]+=similarity*rating
      # Sum of all the similarities
      totalSim.setdefault(item2,0)
      totalSim[item2]+=similarity

  # Divide each total score by total weighting to get an average
  rankings=[(score/totalSim[item],item) for item,score in scores.items( )]

  # Return the rankings from highest to lowest
  rankings.sort( )
  rankings.reverse( )
  return rankings

# %%
getRecommendedItems(critics,itemsim,'Toby')
# Out:
# [(3.182634730538922, 'The Night Listener'),
#  (2.5983318700614575, 'Just My Luck'),
#  (2.4730878186968837, 'Lady in the Water')]

# %%
critics
# Out:
# {'Claudia Puig': {'Just My Luck': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 4.0,
#   'The Night Listener': 4.5,
#   'You, Me and Dupree': 2.5},
#  'Gene Seymour': {'Just My Luck': 1.5,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Jack Matthews': {'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Lisa Rose': {'Just My Luck': 3.0,
#   'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 3.5,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 2.5},
#  'Michael Phillips': {'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.0,
#   'Superman Returns': 3.5,
#   'The Night Listener': 4.0},
#  'Mick LaSalle': {'Just My Luck': 2.0,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 3.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 2.0},
#  'Toby': {'Snakes on a Plane': 4.5,
#   'Superman Returns': 4.0,
#   'You, Me and Dupree': 1.0}}

# %% [markdown]
# ## 使用MovieLens数据集

# %%
def loadMovieLens(path='data/movielens'):
  # Get movie titles
  movies={}
  # ingnore
  for line in open(path+'/u.item',errors='ignore'):
    (id,title)=line.split('|')[0:2]
    movies[id]=title
  
  # Load data
  prefs={}
  for line in open(path+'/u.data'):
    (user,movieid,rating,ts)=line.split('\t')
    prefs.setdefault(user,{})
    prefs[user][movies[movieid]]=float(rating)
  return prefs

# %%
prefs=loadMovieLens()
getRecommendations(prefs,'87')
# Out:
# [('unknown', 3.5413864397809474),
#  ('Zeus and Roxanne (1997)', 2.206510468856659),
#  ("Young Poisoner's Handbook, The (1995)", 3.3819077059083833),
#  ('You So Crazy (1994)', 3.0000000000000004),
#  ('Year of the Horse (1997)', 2.0052819344400112),
#  ('Yankee Zulu (1994)', 1.0),
#  ('Wrong Trousers, The (1993)', 4.463287461290221),
#  ('World of Apu, The (Apur Sansar) (1959)', 4.1778711763816165),
#  ("Wooden Man's Bride, The (Wu Kui) (1994)", 2.25602297941656),
#  ('Wonderland (1997)', 3.311760463260967),
#  ('Wonderful, Horrible Life of Leni Riefenstahl, The (1993)',
#   4.145902520049039),
#  ('Women, The (1939)', 3.6135928801753763),
#  ('Woman in Question, The (1950)', 1.0),
#  ('Wolf (1994)', 2.7204784550506167),
#  ('Witness (1985)', 4.0),
#  ('Withnail and I (1987)', 3.542764908918436),
#  ('With Honors (1994)', 3.0330851077633363),
#  ('Wishmaster (1997)', 2.3557287933857696),
#  ('Winter Guest, The (1997)', 2.8557053930981615),
#  ('Winnie the Pooh and the Blustery Day (1968)', 3.9281109691491984),
#  ('Wings of the Dove, The (1997)', 3.7393515394067136),
#  ('Wings of Desire (1987)', 3.897107945317267),
#  ('Wings of Courage (1995)', 4.0),
#  ('Window to Paris (1994)', 4.0),
#  ('Willy Wonka and the Chocolate Factory (1971)', 3.612751543873163),
#  ("William Shakespeare's Romeo and Juliet (1996)", 3.6067214978958018),
#  ('Wild Things (1998)', 3.0744248513311487),
#  ('Wild Reeds (1994)', 2.812468508063751),
#  ('Wild Bunch, The (1969)', 3.8524084317047813),
#  ('Wild Bill (1995)', 2.4216550900284557),
#  ('Wild America (1997)', 2.901681857130963),
#  ('Wife, The (1995)', 3.0),
#  ("Widows' Peak (1994)", 3.488247562470869),
#  ('Whole Wide World, The (1996)', 4.004432142207874),
#  ('White Squall (1996)', 3.459355603243468),
#  ("White Man's Burden (1995)", 1.9485170940829055),
#  ('White Balloon, The (1995)', 2.383985861240904),
#  ('When the Cats Away (Chacun cherche son chat) (1996)', 3.3943767460041245),
#  ('When a Man Loves a Woman (1994)', 3.47219192283593),
#  ('When We Were Kings (1996)', 4.266002300110171),
#  ('When Night Is Falling (1995)', 3.3145831884891965),
#  ("What's Love Got to Do with It (1993)", 3.5138526869410986),
#  ("What's Eating Gilbert Grape (1993)", 3.5050739412754908),
#  ('What Happened Was... (1994)', 2.388196696988663),
#  ("Wes Craven's New Nightmare (1994)", 3.0544571480352642),
#  ("Wend Kuuni (God's Gift) (1982)", 1.0),
#  ('Welcome to the Dollhouse (1995)', 3.4954077114728648),
#  ('Welcome To Sarajevo (1997)', 3.5623178654083874),
#  ('Wedding Singer, The (1998)', 3.360539404238621),
#  ('Wedding Gift, The (1994)', 4.414870784592075),
#  ('Wedding Bell Blues (1996)', 3.0),
#  ('Washington Square (1997)', 3.2990984451837604),
#  ('Warriors of Virtue (1997)', 2.9479293110307916),
#  ('War, The (1994)', 3.2967478479298107),
#  ('War at Home, The (1996)', 2.0),
#  ('War Room, The (1993)', 3.6027438378311407),
#  ('Wallace & Gromit: The Best of Aardman Animation (1996)', 4.485151301801342),
#  ('Walking and Talking (1996)', 4.025981399746679),
#  ('Walking Dead, The (1995)', 2.155780299355793),
#  ('Walkabout (1971)', 3.77300650281692),
#  ('Walk in the Sun, A (1945)', 3.0000000000000004),
#  ('Walk in the Clouds, A (1995)', 3.380268047181648),
#  ('Waiting to Exhale (1995)', 2.8625367790073137),
#  ('Waiting for Guffman (1996)', 4.125839287139456),
#  ('Wag the Dog (1997)', 3.5244965418940275),
#  ('Volcano (1997)', 2.7835286452251684),
#  ('Visitors, The (Visiteurs, Les) (1993)', 2.930837498623245),
#  ('Virtuosity (1995)', 2.8228770798803566),
#  ('Village of the Damned (1995)', 2.7281062259819207),
#  ('Vie est belle, La (Life is Rosey) (1987)', 1.0),
#  ('Very Natural Thing, A (1974)', 1.0),
#  ('Very Brady Sequel, A (1996)', 2.289898570871622),
#  ('Vertigo (1958)', 4.236305631536013),
#  ('Vermont Is For Lovers (1992)', 1.0),
#  ('Vermin (1998)', 1.267142072038529),
#  ('Venice/Venice (1992)', 1.0),
#  ('Vanya on 42nd Street (1994)', 3.3592657531047463),
#  ('Van, The (1996)', 2.4114625554036704),
#  ('Vampire in Brooklyn (1995)', 1.909069096859679),
#  ('Usual Suspects, The (1995)', 4.431079071179517),
#  ('Up Close and Personal (1996)', 3.3172575238161515),
#  ('Unzipped (1995)', 3.8583139093865),
#  ('Until the End of the World (Bis ans Ende der Welt) (1991)',
#   2.8583075272189418),
#  ('Unstrung Heroes (1995)', 3.3616881332783453),
#  ('Unhook the Stars (1996)', 2.7857596926939436),
#  ('Unforgiven (1992)', 3.9147194090689714),
#  ('Unforgettable (1996)', 3.2547156232787025),
#  ('Underworld (1997)', 2.6511930222468565),
#  ('Underneath, The (1995)', 2.3326030700817353),
#  ('Underground (1995)', 2.5492252712035186),
#  ('Under Siege 2: Dark Territory (1995)', 2.495761640115282),
#  ('Unbearable Lightness of Being, The (1988)', 3.2956200409711585),
#  ('Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)',
#   3.929279658415446),
#  ('U.S. Marshalls (1998)', 3.176108801401202),
#  ('U Turn (1997)', 3.1964471018165144),
#  ('Two or Three Things I Know About Her (1966)', 3.1406321238354997),
#  ('Two if by Sea (1996)', 2.410025844998328),
#  ('Two Much (1996)', 2.1572154912477983),
#  ('Two Friends (1986) ', 3.0),
#  ('Two Deaths (1995)', 2.048893494282224),
#  ('Two Bits (1995)', 1.7539222088707327),
#  ('Twisted (1996)', 2.9999999999999996),
#  ('Twin Town (1997)', 1.6253927168234326),
#  ('Twilight (1998)', 2.512705246260096),
#  ('Twelfth Night (1996)', 3.4005758406839908),
#  ('Turning, The (1992)', 2.7237647822125033),
#  ('Turbulence (1997)', 2.602645791437435),
#  ('Turbo: A Power Rangers Movie (1997)', 1.0),
#  ('Truth or Consequences, N.M. (1997)', 1.7335637675139353),
#  ('Trust (1990)', 3.4937013953672036),
#  ('Truman Show, The (1998)', 1.6496605662389987),
#  ('True Romance (1993)', 3.59624601662807),
#  ('True Crime (1995)', 3.334844935097433),
#  ('Trigger Effect, The (1996)', 3.238131063961252),
#  ('Trial by Jury (1994)', 2.4102851120684967),
#  ('Trial and Error (1997)', 2.5683490816125856),
#  ('Trees Lounge (1996)', 3.1485565912053723),
#  ('Traveller (1997)', 3.478768170070092),
#  ('Transformers: The Movie, The (1986)', 2.7933458171498753),
#  ('Trainspotting (1996)', 3.843511334793319),
#  ('Toy Story (1995)', 3.9136786846026026),
#  ('Touki Bouki (Journey of the Hyena) (1973)', 1.0),
#  ('Tough and Deadly (1995)', 1.0032100594548383),
#  ('Touch of Evil (1958)', 3.947701894565158),
#  ('Touch (1997)', 2.6450968978064657),
#  ('Total Eclipse (1995)', 2.1860696356505183),
#  ('Top Hat (1935)', 3.774625314014255),
#  ('Tomorrow Never Dies (1997)', 3.490028889941741),
#  ('Tombstone (1993)', 3.648247640625184),
#  ('Tom and Huck (1995)', 3.157750560405907),
#  ('Tom & Viv (1994)', 2.559258277119574),
#  ('Tokyo Fist (1995)', 4.0),
#  ('To Live (Huozhe) (1994)', 3.339909495585274),
#  ('To Have, or Not (1995)', 1.79366111365693),
#  ('To Gillian on Her 37th Birthday (1996)', 2.9413387192430815),
#  ('To Cross the Rubicon (1991)', 1.0),
#  ('To Catch a Thief (1955)', 4.093104101816696),
#  ('To Be or Not to Be (1942)', 3.544274455728755),
#  ('Titanic (1997)', 4.3276268926829795),
#  ('Tin Men (1987)', 3.0342239898471557),
#  ('Tin Drum, The (Blechtrommel, Die) (1979)', 3.6242717870455303),
#  ('Tin Cup (1996)', 3.223502697058317),
#  ('Timecop (1994)', 3.025991063764994),
#  ('Time to Kill, A (1996)', 3.677884293906037),
#  ('Time Tracers (1995)', 1.7373380301902428),
#  ('Tigrero: A Film That Was Never Made (1994)', 1.0),
#  ('Tie That Binds, The (1995)', 2.2725918229162407),
#  ('Tie Me Up! Tie Me Down! (1990)', 3.1554090982762872),
#  ('Threesome (1994)', 2.9638281912863267),
#  ('Three Wishes (1995)', 3.361386744377759),
#  ('Three Musketeers, The (1993)', 3.374172369379952),
#  ('Three Lives and Only One Death (1996)', 3.0),
#  ('Three Colors: White (1994)', 3.8876873131041836),
#  ('Three Colors: Red (1994)', 4.008212423331544),
#  ('Three Colors: Blue (1993)', 3.905788524248481),
#  ('Three Caballeros, The (1945)', 3.252306307858917),
#  ('Thousand Acres, A (1997)', 3.46028331002032),
#  ('Thirty-Two Short Films About Glenn Gould (1993)', 3.9621301458386373),
#  ('Third Man, The (1949)', 4.281025776217433),
#  ('Thinner (1996)', 2.4535725659794134),
#  ("Things to Do in Denver when You're Dead (1995)", 3.1563246792177058),
#  ('Thin Man, The (1934)', 4.112332101486154),
#  ('Thin Line Between Love and Hate, A (1996)', 2.4644724830270293),
#  ('Thin Blue Line, The (1988)', 3.8122874469200783),
#  ('Thieves (Voleurs, Les) (1996)', 4.015448853389668),
#  ('They Made Me a Criminal (1939)', 5.0),
#  ('Theodore Rex (1995)', 1.4543585289768384),
#  ('The Innocent (1994)', 2.881665288482612),
#  ('The Deadly Cure (1996)', 1.0),
#  ('The Courtyard (1995)', 1.0),
#  ('That Darn Cat! (1997)', 2.0191960932046356),
#  ('That Darn Cat! (1965)', 2.850310949750445),
#  ('Tetsuo II: Body Hammer (1992)', 2.268953622778375),
#  ('Terror in a Texas Town (1958)', 1.0),
#  ('Terminal Velocity (1994)', 2.7276869345673425),
#  ('Temptress Moon (Feng Yue) (1996)', 1.0),
#  ('Telling Lies in America (1997)', 3.1490525818765587),
#  ('Taxi Driver (1976)', 3.968674663629993),
#  ('Target (1995)', 3.0),
#  ('Tank Girl (1995)', 2.6802873551226245),
#  ('Tango Lesson, The (1997)', 3.8029246523769733),
#  ('Talking About Sex (1994)', 1.6940636268605964),
#  ('Tales from the Hood (1995)', 2.0586737357345677),
#  ('Tales from the Crypt Presents: Bordello of Blood (1996)',
#   2.5531134594377245),
#  ('Tales From the Crypt Presents: Demon Knight (1995)', 2.7467753016154126),
#  ('Tainted (1998)', 3.0),
#  ('T-Men (1947)', 1.0),
#  ('Symphonie pastorale, La (1946)', 1.0),
#  ('Sword in the Stone, The (1963)', 3.3817582827587542),
#  ('Switchback (1997)', 3.181946264780546),
#  ('Swiss Family Robinson (1960)', 3.4014650864007243),
#  ('Swingers (1996)', 3.8512515434918977),
#  ('Swept from the Sea (1997)', 1.488105499247275),
#  ('Sweet Nothing (1995)', 3.0),
#  ('Sweet Hereafter, The (1997)', 3.6996749566445453),
#  ('Swan Princess, The (1994)', 2.846637732601851),
#  ('Suture (1993)', 1.4142461477004755),
#  ('Surviving the Game (1994)', 2.390769600147242),
#  ('Surviving Picasso (1996)', 2.9799298135326775),
#  ('Super Mario Bros. (1993)', 2.043058356979671),
#  ('Sunset Park (1996)', 2.3538902390853305),
#  ('Sunset Blvd. (1950)', 4.075726908484641),
#  ('Sunchaser, The (1996)', 2.9999999999999996),
#  ('Sum of Us, The (1994)', 3.7252422313398847),
#  ('Sudden Manhattan (1996)', 1.655313527586403),
#  ('Sudden Death (1995)', 2.65625557162402),
#  ('Substitute, The (1996)', 2.616062972543825),
#  ('Substance of Fire, The (1996)', 3.2068160703631263),
#  ('SubUrbia (1997)', 3.3605132678640155),
#  ('Stupids, The (1996)', 1.7107091456544015),
#  ('Stuart Saves His Family (1995)', 1.9458291229698212),
#  ('Stripes (1981)', 4.062850463028377),
#  ('Striking Distance (1993)', 2.4207884902173196),
#  ('Streetcar Named Desire, A (1951)', 3.789674823196092),
#  ('Street Fighter (1994)', 2.360854538642298),
#  ('Strawberry and Chocolate (Fresa y chocolate) (1993)', 3.6001281672225964),
#  ('Stranger, The (1994)', 2.7553718665344133),
#  ('Stranger in the House (1997)', 1.717301303828269),
#  ('Story of Xinghua, The (1993)', 3.1629888077037767),
#  ('Stonewall (1995)', 4.0),
#  ("Stephen King's The Langoliers (1995)", 2.3635452895686657),
#  ('Stefano Quantestorie (1993)', 1.0),
#  ('Steel (1997)', 1.6890513328358436),
#  ('Stealing Beauty (1996)', 3.1511191179229683),
#  ('Steal Big, Steal Little (1995)', 2.593276415307633),
#  ('Starship Troopers (1997)', 3.3015150767246295),
#  ('Stars Fell on Henrietta, The (1995)', 1.3597939263305374),
#  ('Star Trek: Generations (1994)', 3.445948681230559),
#  ('Star Trek VI: The Undiscovered Country (1991)', 3.3743378456559325),
#  ('Star Trek V: The Final Frontier (1989)', 2.3830516372469916),
#  ('Star Maps (1997)', 3.193078962076459),
#  ("Star Maker, The (Uomo delle stelle, L') (1995)", 2.6932846315785826),
#  ('Star Kid (1997)', 5.0),
#  ('Stand by Me (1986)', 3.850205974543468),
#  ('Stalker (1979)', 3.583178190279999),
#  ('Stalingrad (1993)', 3.066810085859573),
#  ('Stag (1997)', 1.812764924319433),
#  ('Squeeze (1996)', 1.3873144868287248),
#  ('Spy Hard (1996)', 2.3870140128045367),
#  ('Sprung (1997)', 2.0),
#  ('Spitfire Grill, The (1996)', 3.783160572880813),
#  ('Spirits of the Dead (Tre passi nel delirio) (1968)', 2.328675048441847),
#  ('Spice World (1997)', 1.635367865224971),
#  ('Sphere (1998)', 3.2041515565797556),
#  ('Spellbound (1945)', 3.9443661393645963),
#  ('Species (1995)', 2.887676720291258),
#  ('Specialist, The (1994)', 2.1571936352524985),
#  ('Spawn (1997)', 2.634751639579586),
#  ('Spanking the Monkey (1994)', 2.8802426627456583),
#  ('Spanish Prisoner, The (1997)', 4.0),
#  ('Space Jam (1996)', 2.734504896837987),
#  ('Sound of Music, The (1965)', 3.868287547169227),
#  ('Soul Food (1997)', 3.084392804458397),
#  ("Sophie's Choice (1982)", 3.8451637948824815),
#  ('Somewhere in Time (1980)', 3.5415319276286423),
#  ('Somebody to Love (1994)', 1.0),
#  ("Some Mother's Son (1996)", 4.282525635314467),
#  ('Some Like It Hot (1959)', 4.013125369129662),
#  ('Some Kind of Wonderful (1987)', 3.705784486799869),
#  ('Some Folks Call It a Sling Blade (1993)', 4.339023302721374),
#  ('Solo (1996)', 1.774051434884948),
#  ('So Dear to My Heart (1949)', 3.215566786094302),
#  ('Snow White and the Seven Dwarfs (1937)', 3.768176908779392),
#  ('Smoke (1995)', 3.568351916988036),
#  ("Smilla's Sense of Snow (1997)", 3.152250509155278),
#  ('Smile Like Yours, A (1997)', 2.420722728528987),
#  ('Small Faces (1995)', 2.0),
#  ('Sliver (1993)', 2.3573350092409746),
#  ('Slingshot, The (1993)', 3.305072580833213),
#  ('Sling Blade (1996)', 4.127713893237544),
#  ('Sliding Doors (1998)', 3.4478492811663233),
#  ('Sleepover (1995)', 3.0),
#  ('Sixth Man, The (1997)', 3.3620049008526283),
#  ('Six Degrees of Separation (1993)', 3.661833200472692),
#  ('Sirens (1994)', 3.0421996056311906),
#  ('Simple Wish, A (1997)', 1.5176814486999683),
#  ('Simple Twist of Fate, A (1994)', 3.1313531934240437),
#  ('Silence of the Palace, The (Saimt el Qusur) (1994)', 3.0),
#  ('Silence of the Lambs, The (1991)', 4.329337645656439),
#  ('Showgirls (1995)', 1.6680702843999038),
#  ('Show, The (1995)', 2.9344007695395224),
#  ('Short Cuts (1993)', 3.785546371494125),
#  ('Shopping (1994)', 2.0),
#  ('Shooting Fish (1997)', 2.173314355256029),
#  ('Shooter, The (1995)', 1.7987554268985713),
#  ('Shining, The (1980)', 3.7435998203241554),
#  ('Shine (1996)', 4.050432986233935),
#  ('Shiloh (1997)', 3.0156055843815746),
#  ("She's the One (1996)", 2.9731496943551523),
#  ("She's So Lovely (1997)", 2.6303246268490454),
#  ('Shanghai Triad (Yao a yao yao dao waipo qiao) (1995
#  ('Robin Hood: Prince of Thieves (1991)', 3.180576515325453),
#  ('Robin Hood: Men in Tights (1993)', 2.5428304174587235),
#  ("Robert A. Heinlein's The Puppet Masters (1994)", 2.9050510468344766),
#  ('Rob Roy (1995)', 3.5240581917218567),
#  ('Road to Wellville, The (1994)', 2.147100024383966),
#  ('Rising Sun (1993)', 2.9643574003184905),
#  ('Ripe (1996)', 2.0),
#  ('Right Stuff, The (1983)', 3.9717759499172485),
#  ('Ridicule (1996)', 3.5802941314993237),
#  ('Richie Rich (1994)', 2.3651288646406208),
#  ('Richard III (1995)', 3.546902167566958),
#  ("Rich Man's Wife, The (1996)", 2.2549346954085494),
#  ('Rhyme & Reason (1997)', 1.9290691893618064),
#  ('Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)',
#   3.7940108116840676),
#  ('Restoration (1995)', 3.3197194353078348),
#  ('Reservoir Dogs (1992)', 3.9612158467397727),
#  ('Replacement Killers, The (1998)', 3.427818261618899),
#  ('Rent-a-Kid (1995)', 2.832035194645473),
#  ('Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)', 3.0),
#  ('Remains of the Day, The (1993)', 3.723175923288419),
#  ('Relic, The (1997)', 2.8993947128272866),
#  ('Relative Fear (1994)', 1.0),
#  ('Ref, The (1994)', 3.0442043425026637),
#  ('Red Rock West (1992)', 3.644411330298058),
#  ('Red Firecracker, Green Firecracker (1994)', 3.154543793566031),
#  ('Red Corner (1997)', 3.4807390352602203),
#  ('Reckless (1995)', 2.580227125682381),
#  ('Rebel Without a Cause (1955)', 3.8364945013593426),
#  ('Rebecca (1940)', 3.9899692131288265),
#  ('Rear Window (1954)', 4.343003672704541),
#  ('Real Genius (1985)', 3.6811971051754817),
#  ('Ready to Wear (Pret-A-Porter) (1994)', 1.5509452880447436),
#  ('Raw Deal (1948)', 2.0),
#  ('Ransom (1996)', 3.6264257331713243),
#  ('Ran (1985)', 4.065281747988819),
#  ('Raise the Red Lantern (1991)', 4.056929689294368),
#  ('Rainmaker, The (1997)', 3.5134378955461147),
#  ('Radioland Murders (1994)', 3.3537242963126506),
#  ('Race the Sun (1996)', 2.667970992333587),
#  ('Quiz Show (1994)', 3.664790055926245),
#  ('Quiet Room, The (1996)', 4.357499994134492),
#  ('Quick and the Dead, The (1995)', 3.1859726944028295),
#  ('Quest, The (1996)', 2.3265918308188205),
#  ('Queen Margot (Reine Margot, La) (1994)', 3.473236508693325),
#  ('Quartier Mozart (1992)', 1.0),
#  ('Pushing Hands (1992)', 1.543493142171638),
#  ('Purple Noon (1960)', 2.789591603815022),
#  ('Pump Up the Volume (1990)', 3.3629549596134796),
#  ('Psycho (1960)', 3.981227198885492),
#  ('Prophecy, The (1995)', 2.9805453990331623),
#  ('Prophecy II, The (1998)', 2.8097705151978882),
#  ('Promise, The (Versprechen, Das) (1994)', 1.0),
#  ('Promesse, La (1996)', 3.051348024596018),
#  ('Private Parts (1997)', 3.4739204821236593),
#  ('Prisoner of the Mountains (Kavkazsky Plennik) (1996)', 3.2919558478364657),
#  ('Princess Caraboo (1994)', 3.1305168925632096),
#  ('Princess Bride, The (1987)', 4.27847708743408),
#  ('Palmetto (1998)', 3.8424943219044523),
#  ('Pallbearer, The (1996)', 2.0814921201840977),
#  ('Pagemaster, The (1994)', 2.274837450553624),
#  ('Outlaw, The (1943)', 2.5031737832005856),
#  ('Outbreak (1995)', 3.352067063356315),
#  ('Out to Sea (1997)', 2.779069894653373),
#  ('Other Voices, Other Rooms (1997)', 2.9999999999999996),
#  ('Othello (1995)', 3.5616181045577977),
#  ('Oscar & Lucinda (1997)', 3.696526084652247),
#  ('Orlando (1993)', 3.4708110668031438),
#  ('Original Gangstas (1996)', 2.0200031068891233),
#  ('Operation Dumbo Drop (1995)', 2.5333491590144352),
#  ('Open Season (1996)', 1.0016247844387558),
#  ('Only You (1994)', 3.3443191617033468),
#  ('One Night Stand (1997)', 3.2709042867665215),
#  ("One Flew Over the Cuckoo's Nest (1975)", 4.298358088701393),
#  ('One Fine Day (1996)', 3.1421699463899517),
#  ('Once Were Warriors (1994)', 4.082479894359185),
#  ('Once Upon a Time... When We Were Colored (1995)', 3.1767790932340016),
#  ('Once Upon a Time in the West (1969)', 3.733105574989043),
#  ('Once Upon a Time in America (1984)', 3.3194442561107356),
#  ('On Golden Pond (1981)', 3.5989199301025883),
#  ('Omen, The (1976)', 3.3865168895718836),
#  ('Oliver & Company (1988)', 2.859592024962049),
#  ('Old Yeller (1957)', 3.5487979416360966),
#  ('Old Man and the Sea, The (1958)', 3.529073146621729),
#  ('Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)',
#   2.55468841962095),
#  ('Office Killer (1997)', 1.0),
#  ('Of Love and Shadows (1994)', 2.0035504188858972),
#  ('Of Human Bondage (1934)', 3.7275625716544143),
#  ('Object of My Affection, The (1998)', 4.0),
#  ('Nowhere (1997)', 2.0),
#  ('Now and Then (1995)', 3.664506341831523),
#  ('Notorious (1946)', 4.218755646142777),
#  ('Nothing to Lose (1994)', 3.295015385962021),
#  ('Nothing Personal (1995)', 2.0),
#  ('Nosferatu a Venezia (1986)', 2.07031606191775),
#  ('Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)',
#   3.2490769021825257),
#  ('North by Northwest (1959)', 4.286589850363964),
#  ('North (1994)', 2.5307938275648705),
#  ('Normal Life (1996)', 3.0),
#  ("Nobody's Fool (1994)", 3.4819239396909683),
#  ('Nobody Loves Me (Keiner liebt mich) (1994)', 1.0),
#  ('No Escape (1994)', 2.3060351561378907),
#  ('Nnette et Boni (1996)', 3.639754654054236),
#  ('Nixon (1995)', 2.874837134655684),
#  ('Ninotchka (1939)', 3.712050109405825),
#  ('Nina Takes a Lover (1994)', 2.8787525839030437),
#  ('Nil By Mouth (1997)', 1.3833160066284538),
#  ('Nikita (La Femme Nikita) (1990)', 4.025763525880344),
#  ('Nightwatch (1997)', 3.455805401610608),
#  ('Nightmare on Elm Street, A (1984)', 3.1546127042149092),
#  ('Nightmare Before Christmas, The (1993)', 3.4356689600025785),
#  ('Night on Earth (1991)', 3.5158055525017278),
#  ('Night of the Living Dead (1968)', 3.252469046370965),
#  ('Night Flier (1997)', 3.8308596288183026),
#  ('Night Falls on Manhattan (1997)', 3.353118591494287),
#  ('Nico Icon (1995)', 3.0),
#  ('Money Train (1995)', 2.571461743408728),
#  ('Money Talks (1997)', 2.6723783247585793),
#  ('Mondo (1996)', 3.085709553101),
#  ('Moll Flanders (1996)', 3.430669309128326),
#  ('Modern Affair, A (1995)', 1.0),
#  ('Mixed Nuts (1994)', 2.406383606730804),
#  ('Misrables, Les (1995)', 3.6944422897100218),
#  ('Mirror Has Two Faces, The (1996)', 3.3303582614362925),
#  ('Mirage (1995)', 3.0),
#  ('Miracle on 34th Street (1994)', 3.9045981769029554),
#  ('Mina Tannenbaum (1994)', 2.7825650235236465),
#  ('Mimic (1997)', 2.7693965553927637),
#  ("Miller's Crossing (1990)", 3.6517539066965514),
#  ('Mille bolle blu (1993)', 1.0),
#  ('Mighty, The (1998)', 1.0),
#  ('Mighty Morphin Power Rangers: The Movie (1995)', 2.4423111502424146),
#  ('Midnight in the Garden of Good and Evil (1997)', 3.2364354987691284),
#  ('Midnight Dancers (Sibak) (1994)', 2.512838566946522),
#  ("Microcosmos: Le peuple de l'herbe (1996)", 3.1510855664699355),
#  ('Michael Collins (1996)', 3.563724276378911),
#  ('Miami Rhapsody (1995)', 2.441886229183251),
#  ('Metro (1997)', 2.718051762297738),
#  ('Metisse (Caf au Lait) (1993)', 2.2417351011483304),
#  ('Mercury Rising (1998)', 3.3244381500135654),
#  ('Menace II Society (1993)', 3.4114116681538813),
#  ('Men in Black (1997)', 3.8100818945749237),
#  ('Men With Guns (1997)', 3.3258032601583523),
#  ('Meet Wally Sparks (1997)', 1.6510621985793852),
#  ('Meet Me in St. Louis (1944)', 3.379073287601775),
#  ('Meet John Doe (1941)', 4.137097913340735),
#  ('Mediterraneo (1991)', 3.817538832803089),
#  ("McHale's Navy (1997)", 2.174197558408001),
#  ('Maybe, Maybe Not (Bewegte Mann, Der) (1994)', 3.1954481659242315),
#  ('Maya Lin: A Strong Clear Vision (1994)', 4.427520682864958),
#  ('Maximum Risk (1996)', 2.734878366499084),
#  ('MatchMaker, The (1997)', 2.958020195330418),
#  ("Mary Shelley's Frankenstein (1994)", 3.0584021846635476),
#  ('Mary Reilly (1996)', 2.737148799897129),
#  ('Mary Poppins (1964)', 3.7760446859364842),
#  ("Marvin's Room (1996)", 3.3799627735961795),
#  ('Marlene Dietrich: Shadow and Light (1996) ', 5.0),
#  ('Marked for Death (1990)', 2.239857482101725),
#  ('Mark of Zorro, The (1940)', 3.5650831163912002),
#  ("Margaret's Museum (1995)", 3.634806575616388),
#  ('Manon of the Spring (Manon des sources) (1986)', 4.082735075991782),
#  ('Manny & Lo (1996)', 2.8375116057170677),
#  ('Manhattan Murder Mystery (1993)', 3.67229903710187),
#  ('Manhattan (1979)', 3.5365183693332556),
#  ('Man of the Year (1995)', 3.0462973313617803),
#  ('Man of No Importance, A (1994)', 3.516798943194201),
#  ('Man in the Iron Mask, The (1998)', 3.530899373274026),
#  ('Man from Down Under, The (1943)', 1.0),
#  ('Man Without a Face, The (1993)', 3.4666725583042868),
#  ('Man Who Would Be King, The (1975)', 4.102660919591606),
#  ('Man Who Knew Too Little, The (1997)', 2.9492684630495782),
#  ('Kazaam (1996)', 1.6608289373588536),
#  ('Kaspar Hauser (1993)', 4.450979436941035),
#  ('Kansas City (1996)', 2.060436700385746),
#  ('Kama Sutra: A Tale of Love (1996)', 3.4918475780693132),
#  ('Kalifornia (1993)', 3.199163985713354),
#  ('Just Cause (1995)', 3.137675399464183),
#  ('Jury Duty (1995)', 2.130241976510056),
#  ('Juror, The (1996)', 2.8752807600026618),
#  ("Jupiter's Wife (1994)", 4.0),
#  ('Jungle2Jungle (1997)', 2.494349212811966),
#  ('Jungle Book, The (1994)', 3.4770929409379248),
#  ('Jumanji (1995)', 3.4046500373511037),
#  ('Judgment Night (1993)', 2.6734294209633727),
#  ('Judge Dredd (1995)', 2.7851548666024253),
#  ('Jude (1996)', 2.9625558171725217),
#  ('Joy Luck Club, The (1993)', 3.7115001045161207),
#  ('Journey of August King, The (1995)', 1.6210341304549167),
#  ('Johns (1996)', 3.0),
#  ('Johnny Mnemonic (1995)', 2.600504846074395),
#  ('Johnny 100 Pesos (1993)', 1.511535956615462),
#  ('Jingle All the Way (1996)', 1.9011385793419244),
#  ('Jerry Maguire (1996)', 3.750142963271635),
#  ('Jerky Boys, The (1994)', 2.756110778547383),
#  ('Jefferson in Paris (1995)', 1.7422377378930418),
#  ('Jean de Florette (1986)', 4.066927237985947),
#  ('Jaws 3-D (1983)', 2.00653292975618),
#  ('Jaws 2 (1978)', 2.6829348268756528),
#  ('Jaws (1975)', 3.81429297487151),
#  ("Jason's Lyric (1994)", 3.012050445704731),
#  ('Jane Eyre (1996)', 3.256134370936467),
#  ('James and the Giant Peach (1996)', 2.957438679271527),
#  ('Jade (1995)', 2.1370285687477253),
#  ("Jackie Chan's First Strike (1996)", 3.2827281416687097),
#  ('Jackie Brown (1997)', 3.6642923245819286),
#  ('Jackal, The (1997)', 3.069443514934653),
#  ('Jack and Sarah (1995)', 2.1078845967896824),
#  ('JLG/JLG - autoportrait de dcembre (1994)', 1.0),
#  ("It's My Party (1995)", 3.1795367699948462),
#  ('It Takes Two (1995)', 2.7412994000736277),
#  ('It Happened One Night (1934)', 4.00746773844504),
#  ('It Could Happen to You (1994)', 3.8171519844687833),
#  ('Island of Dr. Moreau, The (1996)', 2.1946969219497436),
#  ('Invitation, The (Zaproszenie) (1986)', 1.0),
#  ('Inventing the Abbotts (1997)', 3.290774618078248),
#  ('Intimate Relations (1996)', 3.0),
#  ('Interview with the Vampire (1994)', 3.124061891294845),
#  ('Inspector General, The (1949)', 4.01369374640013),
#  ('Innocents, The (1961)', 4.532337612572981),
#  ('Innocent Sleep, The (1995)', 1.5488782671334103),
#  ('Infinity (1996)', 2.5526092562275964),
#  ('Indian in the Cupboard, The (1995)', 2.8658874445861904),
#  ('Indian Summer (1996)', 2.860195093783861),
#  ('Incognito (1997)', 4.019175272923253),
#  ('In the Realm of the Senses (Ai no corrida) (1976)', 1.8626664418664127),
#  ('In the Name of the Father (1993)', 3.820630429037276),
#  ('In the Mouth of Madness (1995)', 2.7812806415392535),
#  ('In the Line of Duty 2 (1987)', 2.3685453474710205),
#  ('Girl in the Cadillac (1995)', 1.0),
#  ('Girl 6 (1996)', 2.601313916417313),
#  ("Gilligan's Island: The Movie (1998)", 1.0263042782599605),
#  ('Gigi (1958)', 3.666218817350174),
#  ('Giant (1956)', 3.824615326873584),
#  ('Ghosts of Mississippi (1996)', 3.5927740735860363),
#  ('Ghost in the Shell (Kokaku kidotai) (1995)', 3.596892002566514),
#  ('Ghost and the Darkness, The (1996)', 3.264166384152715),
#  ('Ghost and Mrs. Muir, The (1947)', 3.6292919473669887),
#  ('Ghost (1990)', 3.5297234004105382),
#  ('Getting Even with Dad (1994)', 1.5414896344490316),
#  ('Getting Away With Murder (1996)', 1.0),
#  ('Getaway, The (1994)', 2.369968037384042),
#  ('Get on the Bus (1996)', 3.3656767989269074),
#  ('Geronimo: An American Legend (1993)', 3.0528393912870055),
#  ('Germinal (1993)', 2.2500049343522806),
#  ('Georgia (1995)', 3.0589721065561633),
#  ('George of the Jungle (1997)', 2.836629293992611),
#  ('Gay Divorcee, The (1934)', 3.9905865129669404),
#  ('Gattaca (1997)', 3.6690173370889125),
#  ('Gate of Heavenly Peace, The (1995)', 4.0),
#  ('Gaslight (1944)', 3.9856647093180935),
#  ('Garden of Finzi-Contini, The (Giardino dei Finzi-Contini, Il) (1970)',
#   4.056113938391495),
#  ('Gang Related (1997)', 2.3868753220477137),
#  ('Gandhi (1982)', 4.0359986668509364),
#  ('Game, The (1997)', 3.5801079778251674),
#  ('Gabbeh (1996)', 2.8864341944823244),
#  ('G.I. Jane (1997)', 3.3605999268110462),
#  ('Funny Face (1957)', 3.4977630106686752),
#  ('Funeral, The (1996)', 1.9446399819443203),
#  ('Full Speed (1996)', 2.9477896803477317),
#  ('Full Monty, The (1997)', 3.916517707088933),
#  ('From Dusk Till Dawn (1996)', 3.0892506183894106),
#  ('Frisk (1995)', 2.0606509225637337),
#  ('Frighteners, The (1996)', 3.2023413396150127),
#  ('Fried Green Tomatoes (1991)', 3.797116707654085),
#  ('Friday (1995)', 3.2622761483174103),
#  ('Fresh (1994)', 4.133102599336487),
#  ('French Twist (Gazon maudit) (1995)', 3.0856002046433733),
#  ('Freeway (1996)', 3.1066111377003764),
#  ('Free Willy 3: The Rescue (1997)', 1.8460836390421098),
#  ('Free Willy 2: The Adventure Home (1995)', 1.9831069263227),
#  ('Free Willy (1993)', 2.456719565587147),
#  ('Frankie Starlight (1995)', 2.823842887627809),
#  ('Foxfire (1996)', 2.6135974163124573),
#  ('Fox and the Hound, The (1981)', 3.20049163074472),
#  ('Four Rooms (1995)', 2.9837118145336983),
#  ('Four Days in September (1997)', 4.224125635296416),
#  ('Forrest Gump (1994)', 4.005221741815447),
#  ('Foreign Student (1994)', 2.0),
#  ('Foreign Correspondent (1940)', 3.9167266578235864),
#  ('Forbidden Planet (1956)', 3.8166397518709143),
#  ('Forbidden Christ, The (Cristo proibito, Il) (1950)', 2.6639931149351197),
#  ('For the Moment (1994)', 1.3837658692423516),
#  ('For Whom the Bell Tolls (1943)', 4.058995999857309),
#  ('For Richer or Poorer (1997)', 2.2975570336402376),
#  ('For Love or Money (1993)', 2.7585006351095607),
#  ('For Ever Mozart (1996)', 1.5809717302430872),
#  ('Fools Rush In (1997)', 3.134144797344739),
#  ('Fog, The (1980)', 2.565945027217632),
#  ('Fly Away Home (1996)', 3.6387768751585257),
#  ('Fluke (1995)', 2.41813228270114),
#  ('Flubber (1997)', 2.837641331112179),
#  ('Flower of My Secret, The (Flor de mi secreto, La) (1995)',
#   2.963665927816808),
#  ('Flirting With Disaster (1996)', 3.499592355700884),
#  ('Flirt (1995)', 3.465631558990375),
#  ('Flipper (1996)', 1.9924869377133467),
#  ('Flintstones, The (1994)', 2.0389071066976783),
#  ('Flesh and Bone (1993)', 2.997046725426813),
#  ('Fled (1996)', 2.560746499911504),
#  ('First Knight (1995)', 2.968925058038452),
#  ('First Kid (1996)', 2.9373244160442864),
#  ('Firm, The (1993)', 3.436799865715864),
#  ('Firestorm (1998)', 3.5613149320959447),
#  ('Fire on the Mountain (1996)', 3.0),
#  ('Fire Down Below (1997)', 3.0426117005781013),
#  ('Fille seule, La (A Single Girl) (1995)', 3.0),
#  ('Fifth Element, The (1997)', 3.516533700703649),
#  ('Fierce Creatures (1997)', 3.267005565721419),
#  ('Field of Dreams (1989)', 3.8514443764907265),
#  ('Female Perversions (1996)', 2.5143956130561174),
#  ('Feeling Minnesota (1996)', 2.5996626987117577),
#  ('Feast of July (1995)', 2.3360765523865514),
#  ...]

# %%
itemsim=calculateSimilarItems(prefs,n=50)
getRecommendedItems(prefs,itemsim,'87')[:30]
# Out:
# [(5.0, "What's Eating Gilbert Grape (1993)"),
#  (5.0, 'Vertigo (1958)'),
#  (5.0, 'Usual Suspects, The (1995)'),
#  (5.0, 'Toy Story (1995)'),
#  (5.0, 'Titanic (1997)'),
#  (5.0, 'Sword in the Stone, The (1963)'),
#  (5.0, 'Stand by Me (1986)'),
#  (5.0, 'Sling Blade (1996)'),
#  (5.0, 'Silence of the Lambs, The (1991)'),
#  (5.0, 'Shining, The (1980)'),
#  (5.0, 'Shine (1996)'),
#  (5.0, 'Sense and Sensibility (1995)'),
#  (5.0, 'Scream (1996)'),
#  (5.0, 'Rumble in the Bronx (1995)'),
#  (5.0, 'Rock, The (1996)'),
#  (5.0, 'Robin Hood: Prince of Thieves (1991)'),
#  (5.0, 'Reservoir Dogs (1992)'),
#  (5.0, 'Police Story 4: Project S (Chao ji ji hua) (1993)'),
#  (5.0, 'House of the Spirits, The (1993)'),
#  (5.0, 'Fresh (1994)'),
#  (5.0, 'Day the Sun Turned Cold, The (Tianguo niezi) (1994)'),
#  (5.0, 'Before the Rain (Pred dozhdot) (1994)'),
#  (5.0, 'Assignment, The (1997)'),
#  (5.0, '1-900 (1994)'),
#  (4.888888888888889, "Ed's Next Move (1996)"),
#  (4.833333333333333, 'Anna (1996)'),
#  (4.8, 'Dark City (1998)'),
#  (4.777777777777778,
#   'Flower of My Secret, The (Flor de mi secreto, La) (1995)'),
#  (4.75, 'Broken English (1996)'),
#  (4.75, ' kldum klaka (Cold Fever) (1994)')]
